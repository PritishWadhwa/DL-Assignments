# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import spacy
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.optim as optim
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
from torch.utils.data import DataLoader, TensorDataset, Dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = 'cpu'
from tqdm import tqdm
from transformers import AutoTokenizer, AutoModel
from sentence_transformers import SentenceTransformer

# %%
#Reading csv file
train = pd.read_csv("./train_a2.csv")
test = pd.read_csv("test_a2.csv")
train
# Out:
#                                               utterance  act
# 0     Say , Jim , how about going for a few beers af...    3
# 1      You know that is tempting but is really not g...    4
# 2        What do you mean ? It will help us to relax .     2
# 3      Do you really think so ? I don't . It will ju...    2
# 4      I guess you are right.But what shall we do ? ...    2
# ...                                                 ...  ...
# 5085               Tom and Helen got married at last .     1
# 5086   How did you know that ? I heart Tom ’ s fathe...    2
# 5087           I was invited to attend their wedding .     1
# 5088   It ’ s great . Although his father didn ’ t a...    1
# 5089                              How moving love is .     1
#
# [5090 rows x 2 columns]

# %%
Xtrain = train.utterance
ytrain = train.act - 1
Xtest = test.utterance
ytest = test.act - 1

# %%
def lowerCase(df):
  df= df.apply(lambda x: x.lower())
  return df

Xtrain = lowerCase(Xtrain)
Xtest = lowerCase(Xtest)

# %%
Xtrain
# Out:
# 0       say , jim , how about going for a few beers af...
# 1        you know that is tempting but is really not g...
# 2          what do you mean ? it will help us to relax .
# 3        do you really think so ? i don't . it will ju...
# 4        i guess you are right.but what shall we do ? ...
#                               ...
# 5085                 tom and helen got married at last .
# 5086     how did you know that ? i heart tom ’ s fathe...
# 5087             i was invited to attend their wedding .
# 5088     it ’ s great . although his father didn ’ t a...
# 5089                                how moving love is .
# Name: utterance, Length: 5090, dtype: object

# %%
import contractions
def contractionExpand(text):
  return contractions.fix(text)

Xtrain = Xtrain.apply(lambda x: contractionExpand(x))

# %%
Xtest = Xtest.apply(lambda x: contractionExpand(x))

# %%
Xtrain
# Out:
# 0       say , jim , how about going for a few beers af...
# 1        you know that is tempting but is really not g...
# 2          what do you mean ? it will help us to relax .
# 3        do you really think so ? i do not . it will j...
# 4        i guess you are right.but what shall we do ? ...
#                               ...
# 5085                 tom and helen got married at last .
# 5086     how did you know that ? i heart tom ’ s fathe...
# 5087             i was invited to attend their wedding .
# 5088     it ’ s great . although his father didn ’ t a...
# 5089                                how moving love is .
# Name: utterance, Length: 5090, dtype: object

# %%
import nltk
nltk.download('punkt')

def tokenize(text):
  tokens = nltk.word_tokenize(text)
  return tokens

Xtrain = Xtrain.apply(lambda x: tokenize(x))
# Out:
# [nltk_data] Downloading package punkt to /home/mann/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
Xtest = Xtest.apply(lambda x: tokenize(x))

# %%
max_seq_len = len(max(Xtrain, key=len))

# %%
max_seq_len_test = len(max(Xtest, key=len))

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove.6B.zip
# !ls -lat

# %%
from nltk.corpus import stopwords
import string
sw = stopwords.words('english')

# %%
def remove_stopwords(data):
    for i in tqdm(range(len(data))):
        data[i] = [word for word in data[i] if word not in sw and word not in string.punctuation]
    return data

# %%
Xtrain = remove_stopwords(Xtrain)
Xtest = remove_stopwords(Xtest)
# Out:
# 100%|██████████| 5090/5090 [00:00<00:00, 22030.61it/s]
# 100%|██████████| 722/722 [00:00<00:00, 19928.32it/s]

# %%
sbert_model = SentenceTransformer('all-mpnet-base-v2')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
Xtrain = [[' '.join(i)] for i in Xtrain]

# %%
Xtrain = [i[0] for i in Xtrain]

# %%
Xtest = [[' '.join(i)] for i in Xtest]

# %%
Xtest = [i[0] for i in Xtest]

# %%
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/nli-bert-base')
# Out:
# Downloading:   0%|          | 0.00/375 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
Xtrain2 = []
ytrain2 = []
Xtest2 = []
ytest2 = []
for i in tqdm(range(2, len(Xtrain))):
    newStr = ""
#     Xtrain2.append(Xtrain[i] + tokenizer.sep_token + Xtrain[i-4] + ' '+Xtrain[i-3] + ' '+Xtrain[i-2] + ' '+Xtrain[i-1] + ' ' + Xtrain[i])
    Xtrain2.append(Xtrain[i-2] + ' '+Xtrain[i-1] + ' ' + Xtrain[i])
    ytrain2.append(ytrain[i])
# for i in tqdm(range(1, len(Xtest))):
#     Xtest2.append(Xtest[i-1] + ' ' + Xtest[i])
#     ytest2.append(ytest[i])
# Out:
# 100%|██████████| 5088/5088 [00:00<00:00, 167665.39it/s]

# %%
Xtrain
# Out:
# ['say jim going beers dinner',
#  'know tempting really good fitness',
#  'mean help us relax',
#  'really think make us fat act silly remember last time',
#  'guess right.but shall feel like sitting home',
#  'suggest walk gym play singsong meet friends',
#  'good idea hear mary sally often go play pingpong.perhaps make foursome',
#  'sounds great willing could ask go dancing us.that excellent exercise fun',
#  'good.let go',
#  'right',
#  'push-ups',
#  'course piece cake believe 30 push-ups minute',
#  'really think impossible',
#  'mean 30 push-ups',
#  'yeah',
#  'easy exercise everyday make',
#  'study radio',
#  'listen background music',
#  'difference',
#  'radio many comerials',
#  'true buy record player',
#  'right',
#  'right soon terrified watched fall wire',
#  'worry.he acrobat 。',
#  'see',
#  'hey john nice skates new',
#  'yeah got started playing ice hockey community league finally got new skates',
#  'position play',
#  '’ defender ’ lot fun ’ able skate fast defense',
#  'yeah ’ pretty big guy play goalie',
#  'oh yeah team',
#  'rockets',
#  'really think play guys next week well go practice see later',
#  'right see later',
#  'hey lydia reading',
#  '’ looking horoscope month outlook positive says take vacation someplace exotic passionate summer fling',
#  'talking let see ... horoscopes',
#  '’ prediction month based zodiac sign different sign month date born born april 15th ’ aries born',
#  'january 5th',
#  'let ’ see ’ capricorn says feeling stress work could see new exciting developments love life looks like ’ interesting summers',
#  '’ bogus feel stress work love life practically nonexistent zodiac stuff bunch nonsense',
#  '’ astrology sign tell lot personality see says aries energetic loves socialize',
#  'well certainly match criteria ’ broad could apply anyone say',
#  'capricorn serious-minded practical likes things conventional ways sounds like',
#  'frank ’ getting married believe',
#  'really',
#  'yes loves girl much',
#  'marring',
#  'girl met holiday spain think',
#  'set date wedding',
#  'yet',
#  'hear bought new house northern suburbs',
#  '’ right bought day came market',
#  'kind house',
#  '’ wonderful spanish style',
#  'oh love roof tiles spanish style houses',
#  '’ bargaining house like river side costs double price',
#  'great two bedroom house',
#  'three bedrooms three beds living room twelve-foot ceiling ’ two-car garage',
#  '’ nice area ’ good investment',
#  'yeas buy house',
#  'untill end year know wedding',
#  'right congratulations',
#  'thank',
#  'hi becky',
#  'much except mother-in-law driving wall',
#  'problem',
#  'loves nit-pick criticizes everything never anything right around',
#  'example',
#  'well last week invited dinner husband problem food listened would seem like fed old meat rotten vegetables nothing please',
#  'see happening know good cook nothing like would ever happen',
#  'also criticizes raise kids',
#  'mother-in-law used thing us disciplining enough disciplining much also complained food fed schools sent everything else sun',
#  'said used stop',
#  'basically sat told felt constant criticizing welcomed advice hoped would let us things understood everything lot peaceful',
#  'sounds like good idea try',
#  "zina 's new programmers working",
#  'hate admit good fast filipino kid genius',
#  'make stars.com deadline us running next week',
#  'close make',
#  "good stars.com starts paying us need vikam 's cash anymore",
#  'need need zina either',
#  'like cooking',
#  'yes like cooking much got hobby 12 years sold',
#  'like',
#  'idea like cooking like taste delicious food',
#  'wonderful',
#  'love trying new recipes usually test friends come',
#  'really hope chance taste forget tell',
#  'certainly',
#  'anyone home jen',
#  'kitchen ... let',
#  'wow really working storm',
#  'know even worked sweat',
#  'look like cooking show host -- messier',
#  'look tan healthy',
#  'thanks got back summer camp',
#  '',
#  'great got try many things first time',
#  'like',
#  'went sailing fishing horseback riding',
#  '’ jealous',
#  'counselors nice best summer ever except mosquitoes',
#  'diana like perfume gave',
#  '’ good tell truth ’ wear perfume',
#  '’ sorry ’ know',
#  '’ right thank',
#  'ah ah ah ...',
#  'right bill.here daily exercise schedule jog breakfast',
#  'jog',
#  'walk work',
#  'walk',
#  'thirty minutes gym lunch time',
#  'oh',
#  'use stairs never elevator',
#  'oh dear',
#  'three times week either swim play racketball hand ball',
#  'oh',
#  'ok stop now.it time dance class',
#  'dance class know',
#  '',
#  'oh ...',
#  'hi bill saw grandma yesterday',
#  'oh',
#  'running around track college walking around track',
#  'grannie always tries stay fit healthy.she always making us kids eat proper foods',
#  'well pays her.how old anyway',
#  '86 next month',
#  'truly amazing',
#  'would like register class today',
#  'problem class would like take',
#  'would much enjoy taking psychology class.because crazy',
#  'two classes still open',
#  'days classes',
#  'first class tuesday thursday class two three',
#  'class',
#  'class monday wednesday 10 12',
#  'sure open classes',
#  'positive',
#  'sign monday wednesday',
#  'okay sign',
#  'dad taping windows',
#  'honey typhoon coming',
#  'really wow go school tomorrow',
#  'jenny come help need prepare food',
#  'ok dad coming',
#  'hi name lean russia',
#  'nice meet lean name alike japan',
#  'english difficult language',
#  'second language always difficult',
#  'true english harder crazy language',
#  'crazy language say',
#  'one letter several pronunciations one word several meanings',
#  'wonder say english crazy language',
#  'help',
#  'hope looking material paper writing quite sure look',
#  'certainly try help topic paper',
#  'paper influence television children',
#  'several possible sources might use topic suggest use computer computer give list every scientific journal talks children television',
#  'thank help',
#  '’ hot dog beer happened miss anything',
#  'yeah cal ripen hit home run',
#  '’ score',
#  'well 3 4 ripen ’ home run made 5 4 since another player first base',
#  'baltimore winning',
#  'right',
#  'really great place watch baseball game',
#  'yeah ’ bad seat place',
#  'fans great like philadelphia',
#  'great idea spend day watching game',
#  'yeah reminds say baseball america ’ favorite pastime',
#  'like pizza',
#  'perfect really hits spot',
#  'light',
#  'sorry smoke',
#  'scared stiff giving first performance',
#  'performance excellent',
#  'thank kindly words',
#  'excuse could please take picture us camera',
#  'sure button press shoot',
#  'one',
#  'focus',
#  'focus-free camera point press button',
#  'right say cheese',
#  'every country face history',
#  'yeah ’ live vacuum traditional values long different history',
#  'sometimes human beings really done something wrong admit first',
#  'always somebody wants turn back true history',
#  'believe things ’ realized daydreaming',
#  'like traveling kathy',
#  'like traveling pleasure get places vacation instance ’ like traveling work waiting buses ...',
#  'getting stuck traffic jams ’ driving',
#  'exactly',
#  'house small buy big one',
#  'wish could afford one',
#  'get loan bank know lpf program provides low cost loans participants home purchases',
#  'course know notice house price skyrocketing',
#  'prof.smith',
#  'ms yang.you speak good english',
#  'thank begin like english even child',
#  'learn',
#  'school china.this first time country',
#  'amazing',
#  'want black white coffee',
#  'white please',
#  'look folk concert tomorrow evening want go',
#  'like folk music much',
#  'kind music like',
#  'like classical music',
#  'much classical music sends sleep',
#  'believe',
#  '’ true',
#  'funny',
#  'another coffee',
#  'like spare time',
#  'like playing chess',
#  'hobbies besides playing chess',
#  'afraid',
#  'hobbies like playing tennis things like',
#  'oh yes like playing basketball',
#  'tell like',
#  'like feeling cooperating others',
#  'john find anywhere',
#  'heard prison',
#  'beg pardon',
#  'john prison copped outstealing',
#  "n't believe ears",
#  'help',
#  'hope looking material paper writing quite sure look',
#  'certainly try help you.what topic paper',
#  'paper influence television children',
#  'several possible sources might use topic suggest use computer computer give list every scientific journal talks children television',
#  'thank help',
#  'hey ted friday',
#  'well day work',
#  '’ great plans',
#  'well ’ working hard lately ’ probably take easy',
#  'sounds nice',
#  'yeah ’ probably stay relax maybe watch movies',
#  'stop',
#  'sure time',
#  'honestly believe world ’ improving every year',
#  'yes think science making us wiser think',
#  '’ think ’ right',
#  'believe industry making us wealthier',
#  '’ believe',
#  'opinion medicine making us healthier',
#  'agree sense ’ miserable ever ’',
#  '’ agree maintain ’ healthier wealthier wiser hundred years ago',
#  '’ opinion mine',
#  'plan birthday',
#  'want picnic friends mum',
#  'party home way get together celebrate',
#  'ok mum invite friends home',
#  'may help',
#  'would like return book',
#  'need',
#  'also want check video',
#  'would like check',
#  '’ need',
#  'library card',
#  '',
#  'make sure take proper care video',
#  '’ problem',
#  'damage video fined',
#  '’ damage',
#  'matter look miserable',
#  'us',
#  'mean us',
#  'well always say busy',
#  'right',
#  'often go back live parents leave son room',
#  '... ... miss parents also miss',
#  'oh remember cut terrible calls say anything',
#  'mean groaned words',
#  'totally perhaps marriage',
#  'hi mary look pale today matter',
#  'think caught cold aching',
#  'would better take medicine good rest hope pretty soon',
#  'thank suppose go see doctor',
#  'feel like going drink long day',
#  'great idea peter could use drink',
#  'new bar across road',
#  'sounds good food fantastic',
#  'agree lunch last week',
#  'excellent sounds like plan',
#  'could tell right time please',
#  'well watch says five past two ’ use rely gaining losing last days',
#  'go fix',
#  'yes',
#  'family record ancestors',
#  'sure mom working family tree years ’ always updating',
#  'copy family tree house ’ love see',
#  'show like think goes back 8 generations far',
#  '’ amazing large extended family',
#  '’ got 30 cousins mom ’ side 10 cousins dad ’ side',
#  'close first-cousins',
#  'ones age close relatives ’ older ’ spend much time used ’ know younger cousins well older ones',
#  'see ’ head household',
#  '’ definitely mother mother definitely matriarch bigger family',
#  '’ interesting grandfather think step-mother',
#  'first quite critical ’ married years ’ starting accept fact father divorced mother',
#  '’ pretty much feel step-mother like grandmother like grandson',
#  'hi mr wang feel like going boating',
#  'sounds interesting gone boating time time',
#  'tomorrow afternoon',
#  'sure shall meet',
#  'gate park',
#  'great look forward meeting',
#  'see',
#  'see',
#  'hear saikei ski resort weekend enjoy',
#  'yes exciting though falls skiing team',
#  'coach teach ski',
#  'course top-level coaches state sports general administration',
#  'could move smoothly',
#  'yes.my face even ached icy wind',
#  'happened afterwards',
#  'skiing excitedly realized one thing-i could stop imagine terrified',
#  'poor girl',
#  'look pale recently',
#  'yeah got much pressure company tobe wrapped upon work',
#  'take good care',
#  'thank',
#  'hey maggy hear david',
#  'david ’ hear anything',
#  'know david new boss',
#  'sorry ’ quite follow',
#  'well heard david fired',
#  'oh shame really hard working',
#  'usually get school',
#  'usually ride bike form transport prefer use',
#  'feel see pedal bicycle feel lazy drive car',
#  'think discourage people using private cars produce much pollution',
#  'agree would find difficult stop using car convenient',
#  'cars might convenient bad environment',
#  'car',
#  'used one though started using bicycle get around found really need',
#  'maybe sold car would tempted use',
#  'could try would save lot money',
#  'true every month spend hundreds dollars gas insurance repairs',
#  'got class riding bicycle every day instead driving get lots exercise',
#  'could stand lose pounds car made lazy never end walking anywhere',
#  'let us go car dealership help try sell car good price',
#  'sounds good let us go',
#  'wrong',
#  'nose joint forgot invite party',
#  'going one year abroad tom',
#  'study study study want learn lot',
#  'going take courses',
#  'yes going take university courses',
#  'sounds hard',
#  'yes think probably best',
#  '’ get lonely',
#  'hey pretty cool guy make friends lot extracurricular activities know like fencing theater something',
#  'lovely weather help water flowers jack',
#  'well think',
#  'do.we watered quite days',
#  'please look sky.don see dark clouds going rain soon',
#  'good.so work.how nice',
#  'think nice',
#  '',
#  'weather report says going rain whole week',
#  'oh afraid flowers die rain',
#  'darn grocery store closed',
#  'yeah one closes ten could drive 24 hour store sixth',
#  'alright everything',
#  'wish store close us open 24 house day',
#  'know schedules weird sometimes little corner store thing within walking distance ’ open get home',
#  'yeah prices high',
#  'know three dollars milk',
#  'think two get married',
#  'count',
#  'think so.yes get along well',
#  'like him.he good',
#  'right sure',
#  'dad',
#  'first go city centre stop something drink visit university museum',
#  'going drink',
#  'coffee shop round corner see big building end road',
#  'yes',
#  'bank coffee shop opposite bank',
#  'good hot chocolate',
#  'stop wait lights turn green',
#  'crossing road must always pay attention around',
#  'sorry far museum',
#  'sure ask directions coffee shop',
#  'find us table get drinks',
#  'going cinema tonight',
#  'great tonight',
#  'sure name film know romantic one',
#  'romantic afraid like thrillers better',
#  'think bloody',
#  'contrary exciting',
#  'feel uncomfortable',
#  'sick',
#  'teacher dragging chalk blackboard set teeth edge',
#  '’ finish writing minute',
#  'made mind getting tattoo',
#  'really sure',
#  'yeah trendy look great want get dragon arm maybe tiger back',
#  'yeah something forever use indelible ink removed laser treatment top heard hurts lot',
#  'really',
#  'course use machine needle pokes skin inserts ink',
#  'oh ’ know thought paint skin something',
#  'think reconsider research tattoos also find nearest tattoo parlor make sure used sterilized needles place hygienic',
#  'maybe get tongue piercing',
#  'excuse screen near steering wheel',
#  'portable tv popular thing',
#  'oh new everyday',
#  'news current affairs documentaries music movies noncommercial ads',
#  'anything interesting',
#  'yes something good informative think many people underestimate value tv education',
#  'agree commercials tv',
#  'course tv stations need make money commercials programs',
#  'makes lot sense tv work well',
#  'always depends transmission satellite signals',
#  'got pay programs',
#  'yes 50 yuan per month',
#  'oh',
#  'dreadful',
#  'look view window',
#  'oh dear ’ terrible expected',
#  '’ awful ’',
#  '’ bear look ’ rather disappointed',
#  '’ helped',
#  'free time nancy',
#  'well like playing violin',
#  'really long playing violin',
#  'ten years far started learning middle school',
#  'really interesting',
#  'sure hobbies',
#  'well like collecting matchbox sure counts though',
#  'course everybody hobby',
#  'tell',
#  'worry find way',
#  'need frustrated',
#  'live without job future',
#  'worry find way',
#  'sports like play',
#  'like baseball basketball',
#  'football',
#  'country football brand new never learned game younger',
#  'popular game america',
#  'yeah heard lot really fun',
#  'one games fun watch play',
#  'football player',
#  'fun friends play two hand touch flag football old play tackle football',
#  'two hand touch flag football',
#  'instead tackling somebody touch two hands flag football grab flag ball carrier wearing',
#  'see safer right',
#  'exactly play every saturdays field tennis courts want learn play little welcome join us',
#  'give try give call let us go together',
#  'ok call saturday morning',
#  'great',
#  'upsets',
#  'parents called usual reminded plan marry late 20s easier said done marry time go date',
#  'mother finding one',
#  'find one course ’ modern girl',
#  'perhaps try three minutes date latest type',
#  'mean dozens opposite sex meet three minutes dimly bar serving alcohol hate idea',
#  'updated virgin three minutes video date know online dating website providing service microphone webcam sigh face-to-face guy talking maximum three minutes',
#  '’ think makes sense three minutes short time',
#  'think find possibility romance within first second meeting someone so-called love first sight',
#  'anyway ’ want post face sale internet like',
#  '’ worry many options using internet dating methods sites operate international standard even got certifications course sites pay membership fee serious professional chance meeting good serious person play games higher',
#  '’ want post personal information internet ’ knowing reading',
#  'going party saturday',
#  'thinking',
#  'yeah heard going lot fun',
#  'really well time start',
#  'starts 8',
#  'well going',
#  'everyone school',
#  'know going fun',
#  'party going dj food drinks',
#  'wow sound like going fun',
#  'going see party',
#  'yeah',
#  'could talk minutes grades',
#  'step office moment concern',
#  'failing',
#  'let us go computer see think well',
#  'pretty sure trouble',
#  'see trying think could improve',
#  'missed classes need make sure come school regular basis',
#  'regular study routine following important right',
#  'try hard',
#  'thanks stopping',
#  'good luck test tomorrow crossing fingers',
#  'thanks',
#  'never ever work together',
#  'happened quarrel',
#  'take materials back please',
#  'ask want involved quarrel',
#  'oh god cheated',
#  'buy',
#  'brick believe stupid damn',
#  'buy brick',
#  'guy sidewalk.he three new boxes panasonic video camera boxes.he said get rid quick',
#  '',
#  'said would sell one twenty dollars four-hundred-dollar camera twenty bucks',
#  'brick',
#  'yes',
#  'believe stupid open box',
#  'wanted said box still plastic wrap store.if opened people believe new',
#  'boxes wrapped plastic',
#  'yes kind perfect plastic wrap comes new products.look even bar-code price sticker looked brand new',
#  'would guy selling new video cameras twenty dollars',
#  'said get rid stolen',
#  'aha understand.you trying buy stolen goods sidewalk.so think deserve get cheated',
#  "c'mon blame thought new camera could use it.we even thinking buying camera understand could perfect-looking box",
#  'problem.he friend works shop plastic wrap easy.and probably shop got boxes from.maybe friend works electronics store sell video cameras there.probably couple video camera boxes lying around.so get idea wrapping bricks sell fools like you.twenty dollars brick good profit sell enough bricks',
#  'right sarah fool believe could fall trick',
#  'clock right',
#  'afraid gains little',
#  'many minutes',
#  'two',
#  'hey mary',
#  'last night met great guy bar wonderful time decided meet tonight',
#  'oh exciting guy look like hot',
#  'well think first started talking found extremely funny witty could stop laughing jokes much common like team music amazingly love chinese food feeling going great friends',
#  'seems two good match qualities look friend',
#  'nothing definite think list anything first meet somebody usually tell whether person going good friend seems radar helping spot new friends',
#  'well something never heard ask value friend would say honesty',
#  'agree expect close relationship dishonest person people turn back need',
#  'yeah know friend need friend indeed need fair-weather friends either',
#  '’ ’ look good',
#  'yeah head hurts ’ ’ physics class day ’ killer',
#  'liked physics ’ math really arcs curves velocity cool stuff',
#  'yeah yeah today ’ lesson creation universe',
#  'physics class creation universe ’ pretty unscientific language sounds religious',
#  '’ religion take theory big bang.how possible stuff universe comes explosion ’ better atlas carrying globe back african myths turtles stuff',
#  'turtles whatever ... look ’ required creation matter imbalance particles anti-particles least ’ math says',
#  'math sheath ’ evidence',
#  'evidence know edwin hubble ’ guy early twentieth century first scientist measure drift matter universe thus advancing notions expanding universe would expanding well big bang ... duh',
#  'anyway ’ theory people go around touting theories ’ scientific rigor',
#  'dude ’ equivocate theory becomes theory withstanding rigorous testing slept class ’',
#  'today people advocate lifelong learning people different views lifelong learning understand lifelong learning',
#  'think lifelong learning concept never soon late learning',
#  'mean studying time',
#  'think think attitude towards learning one open new ideas decisions skills behaviors',
#  'axiom teach old dog new tricks work longer',
#  'right lifelong learning finding learning opportunities ages numerous contexts',
#  'yes agree retired participate programs keep momentally active',
#  'keep changing world one must involved lifelong learning ready accept new things',
#  'know recently teaching french',
#  'really great know company lot clients france',
#  'yes want learn french develop career',
#  'old',
#  'nine ... ten may 1st.when birthday',
#  'older ten april 14th',
#  'going birthday party',
#  'maybe ask mother',
#  'smells like ashtray',
#  'hi honey ’ wrong look face',
#  '’ wrong thought agreed going quit smoking',
#  'said going cut different ’ expect go cold turkey overnight',
#  'look ways quit try nicotine patch nicotine chewing gum spend fortune cigarettes every month laws cracking allowing smoking public place ’ like light like',
#  'know know trying ’ willpower quit ’ fight urge reach pack smokes morning coffee lunch please understand',
#  'fine want divorce',
#  'shivering',
#  'freezing',
#  'seems get antsy hear praise another guy',
#  'get antsy praise guy may taken ride guy like',
#  'come think way',
#  'seem lost vigilance watch',
#  'reason distrust never caused harm',
#  'anything sounds fishy',
#  'nothing smells rat told all-right guy',
#  'all-right guy right let us talk something else instead',
#  'cheese tastes like cardboard',
#  'think maybe ’ ’ cheap',
#  'signed join company ’ christmas party',
#  'sure join',
#  'know newcomer think might good opportunity get know people departments company relaxed atmosphere',
#  'right company ’ christmas party always amazing occasion everybody relax get know better also time make new friends networking',
#  'hope formal one boss',
#  'formal fun time love game show please dress casually usually abandon drinks careful',
#  '’ worry handle know boss even informal evening make good impression get totally drunk front',
#  "weatherman 's predictions accurate rain tomorrow",
#  'hope would reschedule baseball game',
#  'hi emily know guy',
#  'tall one sure drive works lily',
#  'cute.what dose',
#  'sure manager think',
#  'really going introduce us',
#  'well already taken know wife right',
#  'ring last night said would',
#  'sorry made disappointed',
#  'right rude lunch',
#  'sorry ’ mean apologize',
#  'yarning bored',
#  'forgive darling tired',
#  'hi nicole good weekend',
#  'yes feel tired today',
#  'really',
#  'well saturday cleaned house played tennis sunday hiked country',
#  'bet studied',
#  'yeah studied sunday evening',
#  'well clean house study stayed bed watched tv',
#  'sounds like fun exercise',
#  'sort played golf computer',
#  'parade celebrate national day weekend',
#  'route',
#  'zhongshan circus city bank',
#  'could join',
#  'excuse afraid seat moved books',
#  'oh dear',
#  'must realized somebody',
#  'oh well looked around space waited nobody came sorry taken place',
#  '’ life expectancy country',
#  '’ sure probably 75 years country',
#  '70 think newspaper article talks problems aging population ’ problem soon affect world',
#  'heard government might need increase retirement age otherwise enough workers support young elderly',
#  'perhaps need babies tina gave birth baby boy yesterday',
#  '’ great however many children bad effect enviroment',
#  '’ son days',
#  'oh ’ fine kids seem grow quickly nowadays',
#  '’ teenager know teenagers often rebellious mine good age child',
#  'mine 24 ’ little young ’ suggest wait late twenties even early thirties good career',
#  'yes think ’ right ’ thinking child yet',
#  'big generation gap parents children country',
#  'yes teenagers want live traditional lives want go fun explore world want develop view life parents usually try discourage ’ often succeed',
#  'parents usually give children freedom country sometimes give much freedom',
#  '’ almost impossible get right balance strict kids might ignore lenient might go wild',
#  'going japan year vacation',
#  'ever america',
#  'would really like',
#  'would like',
#  'hey mark long time see',
#  'julie good see',
#  "great got back week 's vacation thailand",
#  'really',
#  'fantastic want come back',
#  'hear beaches thailand beautiful',
#  'people friendly also food delicious mention cheap',
#  'like thai food see much bangkok',
#  'much got enough city life beijing',
#  'know mean could use vacation',
#  'hey would great could go thailand together sometime',
#  'yeah sure would',
#  'could see manager please complaint make',
#  'yes ’ manager madam',
#  'room checked move',
#  'room',
#  '1808 toilet ’ work properly water ’ run shower',
#  '’ awfully sorry hear ’ turn right away',
#  'congratulations vivian grand prize',
#  'great knew would win',
#  'wear red underwear year',
#  '',
#  'tell tell secret',
#  'ok ok whisper promise tell anyone',
#  '',
#  'going concert evening join us',
#  'sorry',
#  '',
#  'snowed since bosses away business',
#  'v work nearly month feel job',
#  'bad.thank help always busy job feel bit tired',
#  'feeling first came work period time feel better sure get used busy job',
#  'also feel work efficiency high strong working ability professional skill seems know really wonderful',
#  'know phrase survival fittest choices',
#  'right work hard',
#  'music on.may pleasure dance',
#  'sorry engaged foxtrot.will next walls right',
#  'certainly',
#  'excuse seat taken',
#  'please feel free',
#  'thanks lot',
#  'work shanghai',
#  'yes',
#  'tourist place amazing much bigger imagined much exciting much see',
#  'say much modern people imagine',
#  'um well let us see ... kansas originally much quieter peaceful place sure',
#  'uh huh ...',
#  'look headline soo mi',
#  'wow many people united states get divorced',
#  'korea',
#  'think korea marriages break couples stay together',
#  'people get married young',
#  'really people get married beforethe age 20',
#  'hmm women usually work get married',
#  'lot women stay home take care families work',
#  'boy beauty fall love first sight',
#  'beauty tree',
#  'course.no girl charming',
#  'young man',
#  'excuse me.where register',
#  'oh pacific pavilion',
#  'large white building',
#  'yeah',
#  'thanks',
#  'education going australia',
#  'going graduate summer',
#  'going work australia back china',
#  'planning return china graduation',
#  'choosing leave foreign country many people reluctant leave superior living environment abroad',
#  'well think personal development much important simply superior living environment',
#  "yeah china 's developing fast development opportunities found almost every corner country",
#  'particular hobbies tom',
#  'oh yes love playing badminton table tennis computer games playing games become favorite',
#  'hear many teenagers spend hours hours sitting computers care health',
#  'better say mindless sit front machine time think stimulating',
#  'play online games full violence',
#  '',
#  'good think spending several hours day playing computer games waste time might well something healthy meaningful',
#  'hope practice self-control',
#  '’ plot new movie',
#  '’ story policemen investigating series strange murders play part detective catch killer ’ little evidence ’ psychological th',
#  'enjoy making movie heard stories disagreement actors director',
#  'disagreement every director ’ worked ’ always disagreed friendly way always resolved differences made movie ’',
#  'critics happy movies ’ made recently bother',
#  'feedback audience great care think critics think',
#  'stunts movie',
#  'wanted insurance company ’ let stunts done stuntman know used stunts ’ leave experts future',
#  'thank much interview',
#  'pleasure seen movie yet',
#  'yes liked much like impressed rachel ’ performance movie ’ going star',
#  'old lady trimming trees',
#  'grandma',
#  'looks healthy.how old',
#  '92',
#  'mom legs killing',
#  'hold successful right away',
#  'oh man best supper last night wife made stir-fry amazing',
#  'love stir fry crispy bitesize vegetables covered mixture soy sauce oyster sauce wilted greens fresh bean sprouts throw onion garlic ginger mmm mmm ’ almost lunchtime would die plate stir fry right',
#  'well keep vegetables ’ take meat stir fry wife made really hearty chunks beef slivers bell peppers onion ...',
#  'call stir fry meat vegetables ’ worst insult could throw chinese stir fry disgrace wok fried equivalent fajita without wrap',
#  'say',
#  'said lovely day go walk',
#  'well feel little tired',
#  'come little labor much health',
#  'wait minutes want finish writing letter',
#  'take long would shame take advantage lovely weather',
#  'long ten minutes go ahead meet park',
#  'believe look near lake',
#  'thank god showed ’ insane think call police',
#  '’ worry ’ call friend take care ’ believe stalking years nut job',
#  'know well ... said ’ pregnant ’ sorry got worked nothing want know ’ purpose ...',
#  '’ apologize moment met day gone ’ thought you.and ’ ’ ... ’ scared veronica closer get worse gets thought mean ’ handle made veronica everything soul mate',
#  'hold ... ’ always matter together tackle whatever life throws us believe us steven',
#  '’ happy hear knew belong together love much',
#  'zina talk something personal',
#  'long take long',
#  'boyfriend says work much spend time',
#  'upset told leave weekend',
#  'said bother coming back said fine',
#  'problem',
#  'mary date john',
#  'ok seems lot common',
#  'oh really great news look like',
#  'tall slim fair-haired',
#  'sounds like pretty cute think',
#  'nice guy considerate impressed smart great sense humor',
#  'oh love first sight see',
#  'say said would call',
#  'maybe busy work wait try think much',
#  'oh steve stop bit nervous call',
#  'come mary total catch bet call worry',
#  'thank steve always encouraging',
#  'friends',
#  'hi francis business trip',
#  'nightmare',
#  '’',
#  'actually business trip successful arrived time nice conversations settled important issues next year',
#  'sounds quite fruitful call still nightmare',
#  'well air line lost luggage return flight lost carry bag tackling officers charge left airport three hours later expected caught traffic jam finally got home totally exhausted found elevator service due blackout',
#  'really sad story trace back luggage',
#  'still waiting call',
#  'take easy sufferings reward',
#  'company decided cancel trip hong kong',
#  'yes sars epidemic effective control yet would better risk',
#  'maybe good things go hong kong take break take things easy',
#  'right maybe work fitness plan start exercise sitting around office day way keeping fit',
#  'good idea let us see get people plan much business days anyway think many people interested',
#  'pair jeans like best',
#  'really like straight legs',
#  'fashionable',
#  'like way sag feel like plumber butt',
#  'style wear boxers',
#  'someone got head give tug',
#  'old fashioned nobody going pull pants',
#  'ask walking invitation',
#  'hi charles matter',
#  'oh car working waiting tow-truck',
#  'ride home',
#  'yes wife coming get',
#  'good live near',
#  'live suburbs',
#  'live downtown parents',
#  'car',
#  'need car walk work',
#  'lucky',
#  'happy anniversary sweetheart',
#  'yes first anniversary many come cheers',
#  'drink thanks making night worth remembering',
#  'well special day say survive first year rest smooth sailing',
#  "good know oh listen band 's playing song",
#  'requested say dancing shoes',
#  'always',
#  'plan birthday',
#  'want picnic friends mum',
#  'party home way get together celebrate',
#  'ok mum invite friends home',
#  'seconds victor',
#  'no.thanks full',
#  'dinner tonight',
#  'would love',
#  'let us say 6:00',
#  'ok',
#  'cigarette',
#  'oh uh ... thanks henry light',
#  'sorry',
#  'thanks lovely day pity ’ duty',
#  '’ stand like ’ got nothing else',
#  'oh ’ possibly',
#  'hi rose busy right',
#  'hi jack working documents manager wants half hour',
#  'well rose',
#  'something need',
#  'free weekend',
#  'yes nothing',
#  'great convenient visit weekend',
#  'beg pardon',
#  'would like call weekend want drop chat',
#  'really well ok welcome',
#  '5 pm saturday good time',
#  'hmm seven treat dinner',
#  'sure would great bring wine',
#  'ok expecting',
#  'time',
#  'shoot pool',
#  '16 balls table 7 solid colored 7 striped colored black 8 ball white ball',
#  '',
#  'hit white ball cue white ball hits colored balls want get colored balls pockets',
#  'know whether hit solid striped one',
#  'beginning matter someone gets one ball set',
#  'get black ball',
#  'black ball final ball pockets',
#  'let us go try',
#  'going hear country-and-western singer tonight',
#  'would enjoy',
#  'pick around 8 00',
#  'ok see',
#  'mosquitos biting',
#  '’ stop scratching everywhere sneaky little jerks',
#  'bug spray',
#  'forgot buy',
#  '’ put',
#  'cover beer way bite us ’ get drunk fall asleep',
#  '’ without doubt best idea ’ let ’',
#  'run thirsty',
#  'stop running around front tv sit watch',
#  'tried stand bald man talking loudly program',
#  'stay away one keeping',
#  'irritable understand program',
#  'right explain later scram',
#  'ok wait fun want',
#  'exactly want thank',
#  'okay ask something direct',
#  'ha like ever one beat around bush',
#  'fair enough give straight bully',
#  'seriously really want',
#  'tell ya got invite really threw loop done complete 180',
#  'know things changed guess settled',
#  'guess',
#  'daughter plans quit present job wants find another says wants get better job higher pay',
#  'seems quite normal pretty much want',
#  'settling start family anyone want get married',
#  'different world becoming colorful friends feel pressure marry want wait right moment',
#  'time right moment',
#  'let universe find us instead forcing love prefer natural love important thing happy love find us later say',
#  'please excuse really going',
#  'yes course.it nice see',
#  'nice see too.and please give regards mrs.robbins',
#  'excuse seat taken',
#  'afraid',
#  'think coming match',
#  'winning piece cake',
#  'bragging',
#  'would reckon taxing increases',
#  'well state benefit lot suppose',
#  'people think',
#  'ah ’ hard say',
#  'still coming place dinner tomorrow night',
#  'course dinner still',
#  'yes wondering roommate planning coming place',
#  'planning walking ways since weather still nice',
#  'thought would listen live bit rough neighborhood street bars probably want walking around dark',
#  'bad',
#  'wish actually lot crime prostitution around',
#  'really never would guessed criminals must come evenings never noticed anything strange house daytime',
#  'favor take taxi would make feel lot better',
#  'ok get around evenings',
#  'first moved walked everywhere within week purse stolen — block away police station always take public transportation',
#  'anything else happened',
#  'nothing else happened seen quite fights streets bars close',
#  'well careful thanks letting know',
#  'jack wonders whether linda likes',
#  'ask',
#  'scared ask',
#  'chicken guy',
#  'understand parents keep beefing complaining daughters able follow suit',
#  "yeah li na 's mother building fire since neighbour 's daughter got married canadian almost driving li na crazy",
#  'li na would ask done',
#  'meek lamb never goes anyone anything good gold know',
#  'john find anywhere',
#  'heard prison',
#  'beg pardon',
#  'john prison now.he copped outstealing',
#  "n't believe ears",
#  'need',
#  'need use internet',
#  'library card right',
#  'yes',
#  'wait right use computers',
#  '’ fine',
#  'would please write name list',
#  '',
#  'call computer free',
#  'log computer',
#  'use number back library card',
#  'thanks ’ sitting',
#  'nice tie wearing',
#  'thank you.but really look right',
#  'certainly.it matches suit perfectly',
#  'go well sweater',
#  'yes.you look smart today',
#  'thank much',
#  'make case',
#  'ask ’ think ’ guilty',
#  'mean saying',
#  'mean ’ fault',
#  'oh yeah',
#  'yes ’ think pitied rather accused',
#  "happy mother 's day mom",
#  'thanks beautiful',
#  'course certainly deserve put us',
#  'forgot put case deserve flowers',
#  'real problem meet people',
#  'maybe help',
#  'never know shake hands tell something',
#  'come country shake hands',
#  'oh yes men women children shake hands time',
#  '’ simple men shake hands women children ’',
#  'women shake hands lot children good manners shake hands',
#  'well good rule follow men hold hand women children wait see',
#  'sounds easy enough',
#  'sure get hang ’ piece cake ’ nothing worry',
#  'sam sorry birthday yesterday completely forgot',
#  'worry keep forgetting everyone birthdays well',
#  'margaret really told found forgotten try phone jane must gone',
#  'yes jane invited dinner new restaurant opened near us',
#  'oh yes know one food',
#  'food excellent jane ordered birthday cake forgot see one',
#  'oh',
#  'yes jane quite upset manager came apologize get free dessert still ...',
#  'would think least could',
#  'end nice evening got ipad birthday present wanted',
#  'great also thinking getting one think could ask jane quiet word margaret birthday far away',
#  'try knowing margaret see immediately',
#  'restaurant meeting smiths',
#  'let us go wait',
#  '',
#  'usually go movies',
#  'usually go free time weekends',
#  'movie theater always crowded weekends like go movies week',
#  'true sometimes tickets cheaper week well',
#  'telling us lie',
#  'hanged lying',
#  'right trouble',
#  'car run petrol',
#  'believe mr fro buy guy think anyway bill gates',
#  'lot nerve telling us ads sucked',
#  'time order balista today want skinny triple latte',
#  'start worrying weight',
#  'feel like drinking whole milk today think fat',
#  'jess chill',
#  'come tara let ’ go window buy two tickets movie starting minutes',
#  '’ break line ’ impatient ’ front line soon',
#  'two tickets please much',
#  'oh ari ’ mean pay invited go tonight let ’ go dutch ’ pay way insist',
#  '’ looking forward film read good review morning ’ newspaper',
#  'great see something light funny change ’ tired heavy drama',
#  'seats okay',
#  '’ fine ’ watch movie without popcorn',
#  'often buy magazines',
#  'buy computer magazine every month keeps up-to date latest developments',
#  '’ find information internet instead',
#  'sometimes takes long find exact information looking besides like read magazine coffee bar sometimes',
#  'online edition magazine',
#  'yes access articles subscription',
#  'subscription',
#  'yes magazine arrives post beginning month every buy magazines',
#  'buy look particularly interesting ’ buy regularly',
#  'mumm burgers smell great perfect day barbecue',
#  "sure glad rain name 's mike gates way",
#  'oh hi barbara johnson nice meet',
#  ...]

# %%
len(Xtrain)
# Out:
# 5090

# %%
len(Xtrain2)
# Out:
# 5088

# %%
train_sentence_embeddings = sbert_model.encode(Xtrain2)

# %%
test_sentence_embeddings = sbert_model.encode(Xtest)

# %%
train_sentence_embeddings.shape, test_sentence_embeddings.shape
# Out:
# ((5088, 768), (722, 768))

# %%
train_sentence_embeddings.shape, len(ytrain2)
# Out:
# ((5088, 768), 5088)

# %%
import torchtext.vocab

glove = torchtext.vocab.GloVe(name = '6B', dim = 100)
# Out:
# 100%|█████████▉| 399999/400000 [00:20<00:00, 19403.23it/s]

# %%
glove.vectors[glove.stoi['the']]
# Out:
# tensor([-0.0382, -0.2449,  0.7281, -0.3996,  0.0832,  0.0440, -0.3914,  0.3344,
#         -0.5755,  0.0875,  0.2879, -0.0673,  0.3091, -0.2638, -0.1323, -0.2076,
#          0.3340, -0.3385, -0.3174, -0.4834,  0.1464, -0.3730,  0.3458,  0.0520,
#          0.4495, -0.4697,  0.0263, -0.5415, -0.1552, -0.1411, -0.0397,  0.2828,
#          0.1439,  0.2346, -0.3102,  0.0862,  0.2040,  0.5262,  0.1716, -0.0824,
#         -0.7179, -0.4153,  0.2033, -0.1276,  0.4137,  0.5519,  0.5791, -0.3348,
#         -0.3656, -0.5486, -0.0629,  0.2658,  0.3020,  0.9977, -0.8048, -3.0243,
#          0.0125, -0.3694,  2.2167,  0.7220, -0.2498,  0.9214,  0.0345,  0.4674,
#          1.1079, -0.1936, -0.0746,  0.2335, -0.0521, -0.2204,  0.0572, -0.1581,
#         -0.3080, -0.4162,  0.3797,  0.1501, -0.5321, -0.2055, -1.2526,  0.0716,
#          0.7056,  0.4974, -0.4206,  0.2615, -1.5380, -0.3022, -0.0734, -0.2831,
#          0.3710, -0.2522,  0.0162, -0.0171, -0.3898,  0.8742, -0.7257, -0.5106,
#         -0.5203, -0.1459,  0.8278,  0.2706])

# %%
Xtrain2
# Out:
# ['say jim going beers dinner know tempting really good fitness mean help us relax',
#  'know tempting really good fitness mean help us relax really think make us fat act silly remember last time',
#  'mean help us relax really think make us fat act silly remember last time guess right.but shall feel like sitting home',
#  'really think make us fat act silly remember last time guess right.but shall feel like sitting home suggest walk gym play singsong meet friends',
#  'guess right.but shall feel like sitting home suggest walk gym play singsong meet friends good idea hear mary sally often go play pingpong.perhaps make foursome',
#  'suggest walk gym play singsong meet friends good idea hear mary sally often go play pingpong.perhaps make foursome sounds great willing could ask go dancing us.that excellent exercise fun',
#  'good idea hear mary sally often go play pingpong.perhaps make foursome sounds great willing could ask go dancing us.that excellent exercise fun good.let go',
#  'sounds great willing could ask go dancing us.that excellent exercise fun good.let go right',
#  'good.let go right push-ups',
#  'right push-ups course piece cake believe 30 push-ups minute',
#  'push-ups course piece cake believe 30 push-ups minute really think impossible',
#  'course piece cake believe 30 push-ups minute really think impossible mean 30 push-ups',
#  'really think impossible mean 30 push-ups yeah',
#  'mean 30 push-ups yeah easy exercise everyday make',
#  'yeah easy exercise everyday make study radio',
#  'easy exercise everyday make study radio listen background music',
#  'study radio listen background music difference',
#  'listen background music difference radio many comerials',
#  'difference radio many comerials true buy record player',
#  'radio many comerials true buy record player right',
#  'true buy record player right right soon terrified watched fall wire',
#  'right right soon terrified watched fall wire worry.he acrobat 。',
#  'right soon terrified watched fall wire worry.he acrobat 。 see',
#  'worry.he acrobat 。 see hey john nice skates new',
#  'see hey john nice skates new yeah got started playing ice hockey community league finally got new skates',
#  'hey john nice skates new yeah got started playing ice hockey community league finally got new skates position play',
#  'yeah got started playing ice hockey community league finally got new skates position play ’ defender ’ lot fun ’ able skate fast defense',
#  'position play ’ defender ’ lot fun ’ able skate fast defense yeah ’ pretty big guy play goalie',
#  '’ defender ’ lot fun ’ able skate fast defense yeah ’ pretty big guy play goalie oh yeah team',
#  'yeah ’ pretty big guy play goalie oh yeah team rockets',
#  'oh yeah team rockets really think play guys next week well go practice see later',
#  'rockets really think play guys next week well go practice see later right see later',
#  'really think play guys next week well go practice see later right see later hey lydia reading',
#  'right see later hey lydia reading ’ looking horoscope month outlook positive says take vacation someplace exotic passionate summer fling',
#  'hey lydia reading ’ looking horoscope month outlook positive says take vacation someplace exotic passionate summer fling talking let see ... horoscopes',
#  '’ looking horoscope month outlook positive says take vacation someplace exotic passionate summer fling talking let see ... horoscopes ’ prediction month based zodiac sign different sign month date born born april 15th ’ aries born',
#  'talking let see ... horoscopes ’ prediction month based zodiac sign different sign month date born born april 15th ’ aries born january 5th',
#  '’ prediction month based zodiac sign different sign month date born born april 15th ’ aries born january 5th let ’ see ’ capricorn says feeling stress work could see new exciting developments love life looks like ’ interesting summers',
#  'january 5th let ’ see ’ capricorn says feeling stress work could see new exciting developments love life looks like ’ interesting summers ’ bogus feel stress work love life practically nonexistent zodiac stuff bunch nonsense',
#  'let ’ see ’ capricorn says feeling stress work could see new exciting developments love life looks like ’ interesting summers ’ bogus feel stress work love life practically nonexistent zodiac stuff bunch nonsense ’ astrology sign tell lot personality see says aries energetic loves socialize',
#  '’ bogus feel stress work love life practically nonexistent zodiac stuff bunch nonsense ’ astrology sign tell lot personality see says aries energetic loves socialize well certainly match criteria ’ broad could apply anyone say',
#  '’ astrology sign tell lot personality see says aries energetic loves socialize well certainly match criteria ’ broad could apply anyone say capricorn serious-minded practical likes things conventional ways sounds like',
#  'well certainly match criteria ’ broad could apply anyone say capricorn serious-minded practical likes things conventional ways sounds like frank ’ getting married believe',
#  'capricorn serious-minded practical likes things conventional ways sounds like frank ’ getting married believe really',
#  'frank ’ getting married believe really yes loves girl much',
#  'really yes loves girl much marring',
#  'yes loves girl much marring girl met holiday spain think',
#  'marring girl met holiday spain think set date wedding',
#  'girl met holiday spain think set date wedding yet',
#  'set date wedding yet hear bought new house northern suburbs',
#  'yet hear bought new house northern suburbs ’ right bought day came market',
#  'hear bought new house northern suburbs ’ right bought day came market kind house',
#  '’ right bought day came market kind house ’ wonderful spanish style',
#  'kind house ’ wonderful spanish style oh love roof tiles spanish style houses',
#  '’ wonderful spanish style oh love roof tiles spanish style houses ’ bargaining house like river side costs double price',
#  'oh love roof tiles spanish style houses ’ bargaining house like river side costs double price great two bedroom house',
#  '’ bargaining house like river side costs double price great two bedroom house three bedrooms three beds living room twelve-foot ceiling ’ two-car garage',
#  'great two bedroom house three bedrooms three beds living room twelve-foot ceiling ’ two-car garage ’ nice area ’ good investment',
#  'three bedrooms three beds living room twelve-foot ceiling ’ two-car garage ’ nice area ’ good investment yeas buy house',
#  '’ nice area ’ good investment yeas buy house untill end year know wedding',
#  'yeas buy house untill end year know wedding right congratulations',
#  'untill end year know wedding right congratulations thank',
#  'right congratulations thank hi becky',
#  'thank hi becky much except mother-in-law driving wall',
#  'hi becky much except mother-in-law driving wall problem',
#  'much except mother-in-law driving wall problem loves nit-pick criticizes everything never anything right around',
#  'problem loves nit-pick criticizes everything never anything right around example',
#  'loves nit-pick criticizes everything never anything right around example well last week invited dinner husband problem food listened would seem like fed old meat rotten vegetables nothing please',
#  'example well last week invited dinner husband problem food listened would seem like fed old meat rotten vegetables nothing please see happening know good cook nothing like would ever happen',
#  'well last week invited dinner husband problem food listened would seem like fed old meat rotten vegetables nothing please see happening know good cook nothing like would ever happen also criticizes raise kids',
#  'see happening know good cook nothing like would ever happen also criticizes raise kids mother-in-law used thing us disciplining enough disciplining much also complained food fed schools sent everything else sun',
#  'also criticizes raise kids mother-in-law used thing us disciplining enough disciplining much also complained food fed schools sent everything else sun said used stop',
#  'mother-in-law used thing us disciplining enough disciplining much also complained food fed schools sent everything else sun said used stop basically sat told felt constant criticizing welcomed advice hoped would let us things understood everything lot peaceful',
#  'said used stop basically sat told felt constant criticizing welcomed advice hoped would let us things understood everything lot peaceful sounds like good idea try',
#  "basically sat told felt constant criticizing welcomed advice hoped would let us things understood everything lot peaceful sounds like good idea try zina 's new programmers working",
#  "sounds like good idea try zina 's new programmers working hate admit good fast filipino kid genius",
#  "zina 's new programmers working hate admit good fast filipino kid genius make stars.com deadline us running next week",
#  'hate admit good fast filipino kid genius make stars.com deadline us running next week close make',
#  "make stars.com deadline us running next week close make good stars.com starts paying us need vikam 's cash anymore",
#  "close make good stars.com starts paying us need vikam 's cash anymore need need zina either",
#  "good stars.com starts paying us need vikam 's cash anymore need need zina either like cooking",
#  'need need zina either like cooking yes like cooking much got hobby 12 years sold',
#  'like cooking yes like cooking much got hobby 12 years sold like',
#  'yes like cooking much got hobby 12 years sold like idea like cooking like taste delicious food',
#  'like idea like cooking like taste delicious food wonderful',
#  'idea like cooking like taste delicious food wonderful love trying new recipes usually test friends come',
#  'wonderful love trying new recipes usually test friends come really hope chance taste forget tell',
#  'love trying new recipes usually test friends come really hope chance taste forget tell certainly',
#  'really hope chance taste forget tell certainly anyone home jen',
#  'certainly anyone home jen kitchen ... let',
#  'anyone home jen kitchen ... let wow really working storm',
#  'kitchen ... let wow really working storm know even worked sweat',
#  'wow really working storm know even worked sweat look like cooking show host -- messier',
#  'know even worked sweat look like cooking show host -- messier look tan healthy',
#  'look like cooking show host -- messier look tan healthy thanks got back summer camp',
#  'look tan healthy thanks got back summer camp ',
#  'thanks got back summer camp  great got try many things first time',
#  ' great got try many things first time like',
#  'great got try many things first time like went sailing fishing horseback riding',
#  'like went sailing fishing horseback riding ’ jealous',
#  'went sailing fishing horseback riding ’ jealous counselors nice best summer ever except mosquitoes',
#  '’ jealous counselors nice best summer ever except mosquitoes diana like perfume gave',
#  'counselors nice best summer ever except mosquitoes diana like perfume gave ’ good tell truth ’ wear perfume',
#  'diana like perfume gave ’ good tell truth ’ wear perfume ’ sorry ’ know',
#  '’ good tell truth ’ wear perfume ’ sorry ’ know ’ right thank',
#  '’ sorry ’ know ’ right thank ah ah ah ...',
#  '’ right thank ah ah ah ... right bill.here daily exercise schedule jog breakfast',
#  'ah ah ah ... right bill.here daily exercise schedule jog breakfast jog',
#  'right bill.here daily exercise schedule jog breakfast jog walk work',
#  'jog walk work walk',
#  'walk work walk thirty minutes gym lunch time',
#  'walk thirty minutes gym lunch time oh',
#  'thirty minutes gym lunch time oh use stairs never elevator',
#  'oh use stairs never elevator oh dear',
#  'use stairs never elevator oh dear three times week either swim play racketball hand ball',
#  'oh dear three times week either swim play racketball hand ball oh',
#  'three times week either swim play racketball hand ball oh ok stop now.it time dance class',
#  'oh ok stop now.it time dance class dance class know',
#  'ok stop now.it time dance class dance class know ',
#  'dance class know  oh ...',
#  ' oh ... hi bill saw grandma yesterday',
#  'oh ... hi bill saw grandma yesterday oh',
#  'hi bill saw grandma yesterday oh running around track college walking around track',
#  'oh running around track college walking around track grannie always tries stay fit healthy.she always making us kids eat proper foods',
#  'running around track college walking around track grannie always tries stay fit healthy.she always making us kids eat proper foods well pays her.how old anyway',
#  'grannie always tries stay fit healthy.she always making us kids eat proper foods well pays her.how old anyway 86 next month',
#  'well pays her.how old anyway 86 next month truly amazing',
#  '86 next month truly amazing would like register class today',
#  'truly amazing would like register class today problem class would like take',
#  'would like register class today problem class would like take would much enjoy taking psychology class.because crazy',
#  'problem class would like take would much enjoy taking psychology class.because crazy two classes still open',
#  'would much enjoy taking psychology class.because crazy two classes still open days classes',
#  'two classes still open days classes first class tuesday thursday class two three',
#  'days classes first class tuesday thursday class two three class',
#  'first class tuesday thursday class two three class class monday wednesday 10 12',
#  'class class monday wednesday 10 12 sure open classes',
#  'class monday wednesday 10 12 sure open classes positive',
#  'sure open classes positive sign monday wednesday',
#  'positive sign monday wednesday okay sign',
#  'sign monday wednesday okay sign dad taping windows',
#  'okay sign dad taping windows honey typhoon coming',
#  'dad taping windows honey typhoon coming really wow go school tomorrow',
#  'honey typhoon coming really wow go school tomorrow jenny come help need prepare food',
#  'really wow go school tomorrow jenny come help need prepare food ok dad coming',
#  'jenny come help need prepare food ok dad coming hi name lean russia',
#  'ok dad coming hi name lean russia nice meet lean name alike japan',
#  'hi name lean russia nice meet lean name alike japan english difficult language',
#  'nice meet lean name alike japan english difficult language second language always difficult',
#  'english difficult language second language always difficult true english harder crazy language',
#  'second language always difficult true english harder crazy language crazy language say',
#  'true english harder crazy language crazy language say one letter several pronunciations one word several meanings',
#  'crazy language say one letter several pronunciations one word several meanings wonder say english crazy language',
#  'one letter several pronunciations one word several meanings wonder say english crazy language help',
#  'wonder say english crazy language help hope looking material paper writing quite sure look',
#  'help hope looking material paper writing quite sure look certainly try help topic paper',
#  'hope looking material paper writing quite sure look certainly try help topic paper paper influence television children',
#  'certainly try help topic paper paper influence television children several possible sources might use topic suggest use computer computer give list every scientific journal talks children television',
#  'paper influence television children several possible sources might use topic suggest use computer computer give list every scientific journal talks children television thank help',
#  'several possible sources might use topic suggest use computer computer give list every scientific journal talks children television thank help ’ hot dog beer happened miss anything',
#  'thank help ’ hot dog beer happened miss anything yeah cal ripen hit home run',
#  '’ hot dog beer happened miss anything yeah cal ripen hit home run ’ score',
#  'yeah cal ripen hit home run ’ score well 3 4 ripen ’ home run made 5 4 since another player first base',
#  '’ score well 3 4 ripen ’ home run made 5 4 since another player first base baltimore winning',
#  'well 3 4 ripen ’ home run made 5 4 since another player first base baltimore winning right',
#  'baltimore winning right really great place watch baseball game',
#  'right really great place watch baseball game yeah ’ bad seat place',
#  'really great place watch baseball game yeah ’ bad seat place fans great like philadelphia',
#  'yeah ’ bad seat place fans great like philadelphia great idea spend day watching game',
#  'fans great like philadelphia great idea spend day watching game yeah reminds say baseball america ’ favorite pastime',
#  'great idea spend day watching game yeah reminds say baseball america ’ favorite pastime like pizza',
#  'yeah reminds say baseball america ’ favorite pastime like pizza perfect really hits spot',
#  'like pizza perfect really hits spot light',
#  'perfect really hits spot light sorry smoke',
#  'light sorry smoke scared stiff giving first performance',
#  'sorry smoke scared stiff giving first performance performance excellent',
#  'scared stiff giving first performance performance excellent thank kindly words',
#  'performance excellent thank kindly words excuse could please take picture us camera',
#  'thank kindly words excuse could please take picture us camera sure button press shoot',
#  'excuse could please take picture us camera sure button press shoot one',
#  'sure button press shoot one focus',
#  'one focus focus-free camera point press button',
#  'focus focus-free camera point press button right say cheese',
#  'focus-free camera point press button right say cheese every country face history',
#  'right say cheese every country face history yeah ’ live vacuum traditional values long different history',
#  'every country face history yeah ’ live vacuum traditional values long different history sometimes human beings really done something wrong admit first',
#  'yeah ’ live vacuum traditional values long different history sometimes human beings really done something wrong admit first always somebody wants turn back true history',
#  'sometimes human beings really done something wrong admit first always somebody wants turn back true history believe things ’ realized daydreaming',
#  'always somebody wants turn back true history believe things ’ realized daydreaming like traveling kathy',
#  'believe things ’ realized daydreaming like traveling kathy like traveling pleasure get places vacation instance ’ like traveling work waiting buses ...',
#  'like traveling kathy like traveling pleasure get places vacation instance ’ like traveling work waiting buses ... getting stuck traffic jams ’ driving',
#  'like traveling pleasure get places vacation instance ’ like traveling work waiting buses ... getting stuck traffic jams ’ driving exactly',
#  'getting stuck traffic jams ’ driving exactly house small buy big one',
#  'exactly house small buy big one wish could afford one',
#  'house small buy big one wish could afford one get loan bank know lpf program provides low cost loans participants home purchases',
#  'wish could afford one get loan bank know lpf program provides low cost loans participants home purchases course know notice house price skyrocketing',
#  'get loan bank know lpf program provides low cost loans participants home purchases course know notice house price skyrocketing prof.smith',
#  'course know notice house price skyrocketing prof.smith ms yang.you speak good english',
#  'prof.smith ms yang.you speak good english thank begin like english even child',
#  'ms yang.you speak good english thank begin like english even child learn',
#  'thank begin like english even child learn school china.this first time country',
#  'learn school china.this first time country amazing',
#  'school china.this first time country amazing want black white coffee',
#  'amazing want black white coffee white please',
#  'want black white coffee white please look folk concert tomorrow evening want go',
#  'white please look folk concert tomorrow evening want go like folk music much',
#  'look folk concert tomorrow evening want go like folk music much kind music like',
#  'like folk music much kind music like like classical music',
#  'kind music like like classical music much classical music sends sleep',
#  'like classical music much classical music sends sleep believe',
#  'much classical music sends sleep believe ’ true',
#  'believe ’ true funny',
#  '’ true funny another coffee',
#  'funny another coffee like spare time',
#  'another coffee like spare time like playing chess',
#  'like spare time like playing chess hobbies besides playing chess',
#  'like playing chess hobbies besides playing chess afraid',
#  'hobbies besides playing chess afraid hobbies like playing tennis things like',
#  'afraid hobbies like playing tennis things like oh yes like playing basketball',
#  'hobbies like playing tennis things like oh yes like playing basketball tell like',
#  'oh yes like playing basketball tell like like feeling cooperating others',
#  'tell like like feeling cooperating others john find anywhere',
#  'like feeling cooperating others john find anywhere heard prison',
#  'john find anywhere heard prison beg pardon',
#  'heard prison beg pardon john prison copped outstealing',
#  "beg pardon john prison copped outstealing n't believe ears",
#  "john prison copped outstealing n't believe ears help",
#  "n't believe ears help hope looking material paper writing quite sure look",
#  'help hope looking material paper writing quite sure look certainly try help you.what topic paper',
#  'hope looking material paper writing quite sure look certainly try help you.what topic paper paper influence television children',
#  'certainly try help you.what topic paper paper influence television children several possible sources might use topic suggest use computer computer give list every scientific journal talks children television',
#  'paper influence television children several possible sources might use topic suggest use computer computer give list every scientific journal talks children television thank help',
#  'several possible sources might use topic suggest use computer computer give list every scientific journal talks children television thank help hey ted friday',
#  'thank help hey ted friday well day work',
#  'hey ted friday well day work ’ great plans',
#  'well day work ’ great plans well ’ working hard lately ’ probably take easy',
#  '’ great plans well ’ working hard lately ’ probably take easy sounds nice',
#  'well ’ working hard lately ’ probably take easy sounds nice yeah ’ probably stay relax maybe watch movies',
#  'sounds nice yeah ’ probably stay relax maybe watch movies stop',
#  'yeah ’ probably stay relax maybe watch movies stop sure time',
#  'stop sure time honestly believe world ’ improving every year',
#  'sure time honestly believe world ’ improving every year yes think science making us wiser think',
#  'honestly believe world ’ improving every year yes think science making us wiser think ’ think ’ right',
#  'yes think science making us wiser think ’ think ’ right believe industry making us wealthier',
#  '’ think ’ right believe industry making us wealthier ’ believe',
#  'believe industry making us wealthier ’ believe opinion medicine making us healthier',
#  '’ believe opinion medicine making us healthier agree sense ’ miserable ever ’',
#  'opinion medicine making us healthier agree sense ’ miserable ever ’ ’ agree maintain ’ healthier wealthier wiser hundred years ago',
#  'agree sense ’ miserable ever ’ ’ agree maintain ’ healthier wealthier wiser hundred years ago ’ opinion mine',
#  '’ agree maintain ’ healthier wealthier wiser hundred years ago ’ opinion mine plan birthday',
#  '’ opinion mine plan birthday want picnic friends mum',
#  'plan birthday want picnic friends mum party home way get together celebrate',
#  'want picnic friends mum party home way get together celebrate ok mum invite friends home',
#  'party home way get together celebrate ok mum invite friends home may help',
#  'ok mum invite friends home may help would like return book',
#  'may help would like return book need',
#  'would like return book need also want check video',
#  'need also want check video would like check',
#  'also want check video would like check ’ need',
#  'would like check ’ need library card',
#  '’ need library card ',
#  'library card  make sure take proper care video',
#  ' make sure take proper care video ’ problem',
#  'make sure take proper care video ’ problem damage video fined',
#  '’ problem damage video fined ’ damage',
#  'damage video fined ’ damage matter look miserable',
#  '’ damage matter look miserable us',
#  'matter look miserable us mean us',
#  'us mean us well always say busy',
#  'mean us well always say busy right',
#  'well always say busy right often go back live parents leave son room',
#  'right often go back live parents leave son room ... ... miss parents also miss',
#  'often go back live parents leave son room ... ... miss parents also miss oh remember cut terrible calls say anything',
#  '... ... miss parents also miss oh remember cut terrible calls say anything mean groaned words',
#  'oh remember cut terrible calls say anything mean groaned words totally perhaps marriage',
#  'mean groaned words totally perhaps marriage hi mary look pale today matter',
#  'totally perhaps marriage hi mary look pale today matter think caught cold aching',
#  'hi mary look pale today matter think caught cold aching would better take medicine good rest hope pretty soon',
#  'think caught cold aching would better take medicine good rest hope pretty soon thank suppose go see doctor',
#  'would better take medicine good rest hope pretty soon thank suppose go see doctor feel like going drink long day',
#  'thank suppose go see doctor feel like going drink long day great idea peter could use drink',
#  'feel like going drink long day great idea peter could use drink new bar across road',
#  'great idea peter could use drink new bar across road sounds good food fantastic',
#  'new bar across road sounds good food fantastic agree lunch last week',
#  'sounds good food fantastic agree lunch last week excellent sounds like plan',
#  'agree lunch last week excellent sounds like plan could tell right time please',
#  'excellent sounds like plan could tell right time please well watch says five past two ’ use rely gaining losing last days',
#  'could tell right time please well watch says five past two ’ use rely gaining losing last days go fix',
#  'well watch says five past two ’ use rely gaining losing last days go fix yes',
#  'go fix yes family record ancestors',
#  'yes family record ancestors sure mom working family tree years ’ always updating',
#  'family record ancestors sure mom working family tree years ’ always updating copy family tree house ’ love see',
#  'sure mom working family tree years ’ always updating copy family tree house ’ love see show like think goes back 8 generations far',
#  'copy family tree house ’ love see show like think goes back 8 generations far ’ amazing large extended family',
#  'show like think goes back 8 generations far ’ amazing large extended family ’ got 30 cousins mom ’ side 10 cousins dad ’ side',
#  '’ amazing large extended family ’ got 30 cousins mom ’ side 10 cousins dad ’ side close first-cousins',
#  '’ got 30 cousins mom ’ side 10 cousins dad ’ side close first-cousins ones age close relatives ’ older ’ spend much time used ’ know younger cousins well older ones',
#  'close first-cousins ones age close relatives ’ older ’ spend much time used ’ know younger cousins well older ones see ’ head household',
#  'ones age close relatives ’ older ’ spend much time used ’ know younger cousins well older ones see ’ head household ’ definitely mother mother definitely matriarch bigger family',
#  'see ’ head household ’ definitely mother mother definitely matriarch bigger family ’ interesting grandfather think step-mother',
#  '’ definitely mother mother definitely matriarch bigger family ’ interesting grandfather think step-mother first quite critical ’ married years ’ starting accept fact father divorced mother',
#  '’ interesting grandfather think step-mother first quite critical ’ married years ’ starting accept fact father divorced mother ’ pretty much feel step-mother like grandmother like grandson',
#  'first quite critical ’ married years ’ starting accept fact father divorced mother ’ pretty much feel step-mother like grandmother like grandson hi mr wang feel like going boating',
#  '’ pretty much feel step-mother like grandmother like grandson hi mr wang feel like going boating sounds interesting gone boating time time',
#  'hi mr wang feel like going boating sounds interesting gone boating time time tomorrow afternoon',
#  'sounds interesting gone boating time time tomorrow afternoon sure shall meet',
#  'tomorrow afternoon sure shall meet gate park',
#  'sure shall meet gate park great look forward meeting',
#  'gate park great look forward meeting see',
#  'great look forward meeting see see',
#  'see see hear saikei ski resort weekend enjoy',
#  'see hear saikei ski resort weekend enjoy yes exciting though falls skiing team',
#  'hear saikei ski resort weekend enjoy yes exciting though falls skiing team coach teach ski',
#  'yes exciting though falls skiing team coach teach ski course top-level coaches state sports general administration',
#  'coach teach ski course top-level coaches state sports general administration could move smoothly',
#  'course top-level coaches state sports general administration could move smoothly yes.my face even ached icy wind',
#  'could move smoothly yes.my face even ached icy wind happened afterwards',
#  'yes.my face even ached icy wind happened afterwards skiing excitedly realized one thing-i could stop imagine terrified',
#  'happened afterwards skiing excitedly realized one thing-i could stop imagine terrified poor girl',
#  'skiing excitedly realized one thing-i could stop imagine terrified poor girl look pale recently',
#  'poor girl look pale recently yeah got much pressure company tobe wrapped upon work',
#  'look pale recently yeah got much pressure company tobe wrapped upon work take good care',
#  'yeah got much pressure company tobe wrapped upon work take good care thank',
#  'take good care thank hey maggy hear david',
#  'thank hey maggy hear david david ’ hear anything',
#  'hey maggy hear david david ’ hear anything know david new boss',
#  'david ’ hear anything know david new boss sorry ’ quite follow',
#  'know david new boss sorry ’ quite follow well heard david fired',
#  'sorry ’ quite follow well heard david fired oh shame really hard working',
#  'well heard david fired oh shame really hard working usually get school',
#  'oh shame really hard working usually get school usually ride bike form transport prefer use',
#  'usually get school usually ride bike form transport prefer use feel see pedal bicycle feel lazy drive car',
#  'usually ride bike form transport prefer use feel see pedal bicycle feel lazy drive car think discourage people using private cars produce much pollution',
#  'feel see pedal bicycle feel lazy drive car think discourage people using private cars produce much pollution agree would find difficult stop using car convenient',
#  'think discourage people using private cars produce much pollution agree would find difficult stop using car convenient cars might convenient bad environment',
#  'agree would find difficult stop using car convenient cars might convenient bad environment car',
#  'cars might convenient bad environment car used one though started using bicycle get around found really need',
#  'car used one though started using bicycle get around found really need maybe sold car would tempted use',
#  'used one though started using bicycle get around found really need maybe sold car would tempted use could try would save lot money',
#  'maybe sold car would tempted use could try would save lot money true every month spend hundreds dollars gas insurance repairs',
#  'could try would save lot money true every month spend hundreds dollars gas insurance repairs got class riding bicycle every day instead driving get lots exercise',
#  'true every month spend hundreds dollars gas insurance repairs got class riding bicycle every day instead driving get lots exercise could stand lose pounds car made lazy never end walking anywhere',
#  'got class riding bicycle every day instead driving get lots exercise could stand lose pounds car made lazy never end walking anywhere let us go car dealership help try sell car good price',
#  'could stand lose pounds car made lazy never end walking anywhere let us go car dealership help try sell car good price sounds good let us go',
#  'let us go car dealership help try sell car good price sounds good let us go wrong',
#  'sounds good let us go wrong nose joint forgot invite party',
#  'wrong nose joint forgot invite party going one year abroad tom',
#  'nose joint forgot invite party going one year abroad tom study study study want learn lot',
#  'going one year abroad tom study study study want learn lot going take courses',
#  'study study study want learn lot going take courses yes going take university courses',
#  'going take courses yes going take university courses sounds hard',
#  'yes going take university courses sounds hard yes think probably best',
#  'sounds hard yes think probably best ’ get lonely',
#  'yes think probably best ’ get lonely hey pretty cool guy make friends lot extracurricular activities know like fencing theater something',
#  '’ get lonely hey pretty cool guy make friends lot extracurricular activities know like fencing theater something lovely weather help water flowers jack',
#  'hey pretty cool guy make friends lot extracurricular activities know like fencing theater something lovely weather help water flowers jack well think',
#  'lovely weather help water flowers jack well think do.we watered quite days',
#  'well think do.we watered quite days please look sky.don see dark clouds going rain soon',
#  'do.we watered quite days please look sky.don see dark clouds going rain soon good.so work.how nice',
#  'please look sky.don see dark clouds going rain soon good.so work.how nice think nice',
#  'good.so work.how nice think nice ',
#  'think nice  weather report says going rain whole week',
#  ' weather report says going rain whole week oh afraid flowers die rain',
#  'weather report says going rain whole week oh afraid flowers die rain darn grocery store closed',
#  'oh afraid flowers die rain darn grocery store closed yeah one closes ten could drive 24 hour store sixth',
#  'darn grocery store closed yeah one closes ten could drive 24 hour store sixth alright everything',
#  'yeah one closes ten could drive 24 hour store sixth alright everything wish store close us open 24 house day',
#  'alright everything wish store close us open 24 house day know schedules weird sometimes little corner store thing within walking distance ’ open get home',
#  'wish store close us open 24 house day know schedules weird sometimes little corner store thing within walking distance ’ open get home yeah prices high',
#  'know schedules weird sometimes little corner store thing within walking distance ’ open get home yeah prices high know three dollars milk',
#  'yeah prices high know three dollars milk think two get married',
#  'know three dollars milk think two get married count',
#  'think two get married count think so.yes get along well',
#  'count think so.yes get along well like him.he good',
#  'think so.yes get along well like him.he good right sure',
#  'like him.he good right sure dad',
#  'right sure dad first go city centre stop something drink visit university museum',
#  'dad first go city centre stop something drink visit university museum going drink',
#  'first go city centre stop something drink visit university museum going drink coffee shop round corner see big building end road',
#  'going drink coffee shop round corner see big building end road yes',
#  'coffee shop round corner see big building end road yes bank coffee shop opposite bank',
#  'yes bank coffee shop opposite bank good hot chocolate',
#  'bank coffee shop opposite bank good hot chocolate stop wait lights turn green',
#  'good hot chocolate stop wait lights turn green crossing road must always pay attention around',
#  'stop wait lights turn green crossing road must always pay attention around sorry far museum',
#  'crossing road must always pay attention around sorry far museum sure ask directions coffee shop',
#  'sorry far museum sure ask directions coffee shop find us table get drinks',
#  'sure ask directions coffee shop find us table get drinks going cinema tonight',
#  'find us table get drinks going cinema tonight great tonight',
#  'going cinema tonight great tonight sure name film know romantic one',
#  'great tonight sure name film know romantic one romantic afraid like thrillers better',
#  'sure name film know romantic one romantic afraid like thrillers better think bloody',
#  'romantic afraid like thrillers better think bloody contrary exciting',
#  'think bloody contrary exciting feel uncomfortable',
#  'contrary exciting feel uncomfortable sick',
#  'feel uncomfortable sick teacher dragging chalk blackboard set teeth edge',
#  'sick teacher dragging chalk blackboard set teeth edge ’ finish writing minute',
#  'teacher dragging chalk blackboard set teeth edge ’ finish writing minute made mind getting tattoo',
#  '’ finish writing minute made mind getting tattoo really sure',
#  'made mind getting tattoo really sure yeah trendy look great want get dragon arm maybe tiger back',
#  'really sure yeah trendy look great want get dragon arm maybe tiger back yeah something forever use indelible ink removed laser treatment top heard hurts lot',
#  'yeah trendy look great want get dragon arm maybe tiger back yeah something forever use indelible ink removed laser treatment top heard hurts lot really',
#  'yeah something forever use indelible ink removed laser treatment top heard hurts lot really course use machine needle pokes skin inserts ink',
#  'really course use machine needle pokes skin inserts ink oh ’ know thought paint skin something',
#  'course use machine needle pokes skin inserts ink oh ’ know thought paint skin something think reconsider research tattoos also find nearest tattoo parlor make sure used sterilized needles place hygienic',
#  'oh ’ know thought paint skin something think reconsider research tattoos also find nearest tattoo parlor make sure used sterilized needles place hygienic maybe get tongue piercing',
#  'think reconsider research tattoos also find nearest tattoo parlor make sure used sterilized needles place hygienic maybe get tongue piercing excuse screen near steering wheel',
#  'maybe get tongue piercing excuse screen near steering wheel portable tv popular thing',
#  'excuse screen near steering wheel portable tv popular thing oh new everyday',
#  'portable tv popular thing oh new everyday news current affairs documentaries music movies noncommercial ads',
#  'oh new everyday news current affairs documentaries music movies noncommercial ads anything interesting',
#  'news current affairs documentaries music movies noncommercial ads anything interesting yes something good informative think many people underestimate value tv education',
#  'anything interesting yes something good informative think many people underestimate value tv education agree commercials tv',
#  'yes something good informative think many people underestimate value tv education agree commercials tv course tv stations need make money commercials programs',
#  'agree commercials tv course tv stations need make money commercials programs makes lot sense tv work well',
#  'course tv stations need make money commercials programs makes lot sense tv work well always depends transmission satellite signals',
#  'makes lot sense tv work well always depends transmission satellite signals got pay programs',
#  'always depends transmission satellite signals got pay programs yes 50 yuan per month',
#  'got pay programs yes 50 yuan per month oh',
#  'yes 50 yuan per month oh dreadful',
#  'oh dreadful look view window',
#  'dreadful look view window oh dear ’ terrible expected',
#  'look view window oh dear ’ terrible expected ’ awful ’',
#  'oh dear ’ terrible expected ’ awful ’ ’ bear look ’ rather disappointed',
#  '’ awful ’ ’ bear look ’ rather disappointed ’ helped',
#  '’ bear look ’ rather disappointed ’ helped free time nancy',
#  '’ helped free time nancy well like playing violin',
#  'free time nancy well like playing violin really long playing violin',
#  'well like playing violin really long playing violin ten years far started learning middle school',
#  'really long playing violin ten years far started learning middle school really interesting',
#  'ten years far started learning middle school really interesting sure hobbies',
#  'really interesting sure hobbies well like collecting matchbox sure counts though',
#  'sure hobbies well like collecting matchbox sure counts though course everybody hobby',
#  'well like collecting matchbox sure counts though course everybody hobby tell',
#  'course everybody hobby tell worry find way',
#  'tell worry find way need frustrated',
#  'worry find way need frustrated live without job future',
#  'need frustrated live without job future worry find way',
#  'live without job future worry find way sports like play',
#  'worry find way sports like play like baseball basketball',
#  'sports like play like baseball basketball football',
#  'like baseball basketball football country football brand new never learned game younger',
#  'football country football brand new never learned game younger popular game america',
#  'country football brand new never learned game younger popular game america yeah heard lot really fun',
#  'popular game america yeah heard lot really fun one games fun watch play',
#  'yeah heard lot really fun one games fun watch play football player',
#  'one games fun watch play football player fun friends play two hand touch flag football old play tackle football',
#  'football player fun friends play two hand touch flag football old play tackle football two hand touch flag football',
#  'fun friends play two hand touch flag football old play tackle football two hand touch flag football instead tackling somebody touch two hands flag football grab flag ball carrier wearing',
#  'two hand touch flag football instead tackling somebody touch two hands flag football grab flag ball carrier wearing see safer right',
#  'instead tackling somebody touch two hands flag football grab flag ball carrier wearing see safer right exactly play every saturdays field tennis courts want learn play little welcome join us',
#  'see safer right exactly play every saturdays field tennis courts want learn play little welcome join us give try give call let us go together',
#  'exactly play every saturdays field tennis courts want learn play little welcome join us give try give call let us go together ok call saturday morning',
#  'give try give call let us go together ok call saturday morning great',
#  'ok call saturday morning great upsets',
#  'great upsets parents called usual reminded plan marry late 20s easier said done marry time go date',
#  'upsets parents called usual reminded plan marry late 20s easier said done marry time go date mother finding one',
#  'parents called usual reminded plan marry late 20s easier said done marry time go date mother finding one find one course ’ modern girl',
#  'mother finding one find one course ’ modern girl perhaps try three minutes date latest type',
#  'find one course ’ modern girl perhaps try three minutes date latest type mean dozens opposite sex meet three minutes dimly bar serving alcohol hate idea',
#  'perhaps try three minutes date latest type mean dozens opposite sex meet three minutes dimly bar serving alcohol hate idea updated virgin three minutes video date know online dating website providing service microphone webcam sigh face-to-face guy talking maximum three minutes',
#  'mean dozens opposite sex meet three minutes dimly bar serving alcohol hate idea updated virgin three minutes video date know online dating website providing service microphone webcam sigh face-to-face guy talking maximum three minutes ’ think makes sense three minutes short time',
#  'updated virgin three minutes video date know online dating website providing service microphone webcam sigh face-to-face guy talking maximum three minutes ’ think makes sense three minutes short time think find possibility romance within first second meeting someone so-called love first sight',
#  '’ think makes sense three minutes short time think find possibility romance within first second meeting someone so-called love first sight anyway ’ want post face sale internet like',
#  'think find possibility romance within first second meeting someone so-called love first sight anyway ’ want post face sale internet like ’ worry many options using internet dating methods sites operate international standard even got certifications course sites pay membership fee serious professional chance meeting good serious person play games higher',
#  'anyway ’ want post face sale internet like ’ worry many options using internet dating methods sites operate international standard even got certifications course sites pay membership fee serious professional chance meeting good serious person play games higher ’ want post personal information internet ’ knowing reading',
#  '’ worry many options using internet dating methods sites operate international standard even got certifications course sites pay membership fee serious professional chance meeting good serious person play games higher ’ want post personal information internet ’ knowing reading going party saturday',
#  '’ want post personal information internet ’ knowing reading going party saturday thinking',
#  'going party saturday thinking yeah heard going lot fun',
#  'thinking yeah heard going lot fun really well time start',
#  'yeah heard going lot fun really well time start starts 8',
#  'really well time start starts 8 well going',
#  'starts 8 well going everyone school',
#  'well going everyone school know going fun',
#  'everyone school know going fun party going dj food drinks',
#  'know going fun party going dj food drinks wow sound like going fun',
#  'party going dj food drinks wow sound like going fun going see party',
#  'wow sound like going fun going see party yeah',
#  'going see party yeah could talk minutes grades',
#  'yeah could talk minutes grades step office moment concern',
#  'could talk minutes grades step office moment concern failing',
#  'step office moment concern failing let us go computer see think well',
#  'failing let us go computer see think well pretty sure trouble',
#  'let us go computer see think well pretty sure trouble see trying think could improve',
#  'pretty sure trouble see trying think could improve missed classes need make sure come school regular basis',
#  'see trying think could improve missed classes need make sure come school regular basis regular study routine following important right',
#  'missed classes need make sure come school regular basis regular study routine following important right try hard',
#  'regular study routine following important right try hard thanks stopping',
#  'try hard thanks stopping good luck test tomorrow crossing fingers',
#  'thanks stopping good luck test tomorrow crossing fingers thanks',
#  'good luck test tomorrow crossing fingers thanks never ever work together',
#  'thanks never ever work together happened quarrel',
#  'never ever work together happened quarrel take materials back please',
#  'happened quarrel take materials back please ask want involved quarrel',
#  'take materials back please ask want involved quarrel oh god cheated',
#  'ask want involved quarrel oh god cheated buy',
#  'oh god cheated buy brick believe stupid damn',
#  'buy brick believe stupid damn buy brick',
#  'brick believe stupid damn buy brick guy sidewalk.he three new boxes panasonic video camera boxes.he said get rid quick',
#  'buy brick guy sidewalk.he three new boxes panasonic video camera boxes.he said get rid quick ',
# ...
#  'mosquitos biting ’ stop scratching everywhere sneaky little jerks bug spray',
#  '’ stop scratching everywhere sneaky little jerks bug spray forgot buy',
#  'bug spray forgot buy ’ put',
#  'forgot buy ’ put cover beer way bite us ’ get drunk fall asleep',
#  '’ put cover beer way bite us ’ get drunk fall asleep ’ without doubt best idea ’ let ’',
#  'cover beer way bite us ’ get drunk fall asleep ’ without doubt best idea ’ let ’ run thirsty',
#  '’ without doubt best idea ’ let ’ run thirsty stop running around front tv sit watch',
#  'run thirsty stop running around front tv sit watch tried stand bald man talking loudly program',
#  'stop running around front tv sit watch tried stand bald man talking loudly program stay away one keeping',
#  'tried stand bald man talking loudly program stay away one keeping irritable understand program',
#  'stay away one keeping irritable understand program right explain later scram',
#  'irritable understand program right explain later scram ok wait fun want',
#  'right explain later scram ok wait fun want exactly want thank',
#  'ok wait fun want exactly want thank okay ask something direct',
#  'exactly want thank okay ask something direct ha like ever one beat around bush',
#  'okay ask something direct ha like ever one beat around bush fair enough give straight bully',
#  'ha like ever one beat around bush fair enough give straight bully seriously really want',
#  'fair enough give straight bully seriously really want tell ya got invite really threw loop done complete 180',
#  'seriously really want tell ya got invite really threw loop done complete 180 know things changed guess settled',
#  'tell ya got invite really threw loop done complete 180 know things changed guess settled guess',
#  'know things changed guess settled guess daughter plans quit present job wants find another says wants get better job higher pay',
#  'guess daughter plans quit present job wants find another says wants get better job higher pay seems quite normal pretty much want',
#  'daughter plans quit present job wants find another says wants get better job higher pay seems quite normal pretty much want settling start family anyone want get married',
#  'seems quite normal pretty much want settling start family anyone want get married different world becoming colorful friends feel pressure marry want wait right moment',
#  'settling start family anyone want get married different world becoming colorful friends feel pressure marry want wait right moment time right moment',
#  'different world becoming colorful friends feel pressure marry want wait right moment time right moment let universe find us instead forcing love prefer natural love important thing happy love find us later say',
#  'time right moment let universe find us instead forcing love prefer natural love important thing happy love find us later say please excuse really going',
#  'let universe find us instead forcing love prefer natural love important thing happy love find us later say please excuse really going yes course.it nice see',
#  'please excuse really going yes course.it nice see nice see too.and please give regards mrs.robbins',
#  'yes course.it nice see nice see too.and please give regards mrs.robbins excuse seat taken',
#  'nice see too.and please give regards mrs.robbins excuse seat taken afraid',
#  'excuse seat taken afraid think coming match',
#  'afraid think coming match winning piece cake',
#  'think coming match winning piece cake bragging',
#  'winning piece cake bragging would reckon taxing increases',
#  'bragging would reckon taxing increases well state benefit lot suppose',
#  'would reckon taxing increases well state benefit lot suppose people think',
#  'well state benefit lot suppose people think ah ’ hard say',
#  'people think ah ’ hard say still coming place dinner tomorrow night',
#  'ah ’ hard say still coming place dinner tomorrow night course dinner still',
#  'still coming place dinner tomorrow night course dinner still yes wondering roommate planning coming place',
#  'course dinner still yes wondering roommate planning coming place planning walking ways since weather still nice',
#  'yes wondering roommate planning coming place planning walking ways since weather still nice thought would listen live bit rough neighborhood street bars probably want walking around dark',
#  'planning walking ways since weather still nice thought would listen live bit rough neighborhood street bars probably want walking around dark bad',
#  'thought would listen live bit rough neighborhood street bars probably want walking around dark bad wish actually lot crime prostitution around',
#  'bad wish actually lot crime prostitution around really never would guessed criminals must come evenings never noticed anything strange house daytime',
#  'wish actually lot crime prostitution around really never would guessed criminals must come evenings never noticed anything strange house daytime favor take taxi would make feel lot better',
#  'really never would guessed criminals must come evenings never noticed anything strange house daytime favor take taxi would make feel lot better ok get around evenings',
#  'favor take taxi would make feel lot better ok get around evenings first moved walked everywhere within week purse stolen — block away police station always take public transportation',
#  'ok get around evenings first moved walked everywhere within week purse stolen — block away police station always take public transportation anything else happened',
#  'first moved walked everywhere within week purse stolen — block away police station always take public transportation anything else happened nothing else happened seen quite fights streets bars close',
#  'anything else happened nothing else happened seen quite fights streets bars close well careful thanks letting know',
#  'nothing else happened seen quite fights streets bars close well careful thanks letting know jack wonders whether linda likes',
#  'well careful thanks letting know jack wonders whether linda likes ask',
#  'jack wonders whether linda likes ask scared ask',
#  'ask scared ask chicken guy',
#  'scared ask chicken guy understand parents keep beefing complaining daughters able follow suit',
#  "chicken guy understand parents keep beefing complaining daughters able follow suit yeah li na 's mother building fire since neighbour 's daughter got married canadian almost driving li na crazy",
#  "understand parents keep beefing complaining daughters able follow suit yeah li na 's mother building fire since neighbour 's daughter got married canadian almost driving li na crazy li na would ask done",
#  "yeah li na 's mother building fire since neighbour 's daughter got married canadian almost driving li na crazy li na would ask done meek lamb never goes anyone anything good gold know",
#  'li na would ask done meek lamb never goes anyone anything good gold know john find anywhere',
#  'meek lamb never goes anyone anything good gold know john find anywhere heard prison',
#  'john find anywhere heard prison beg pardon',
#  'heard prison beg pardon john prison now.he copped outstealing',
#  "beg pardon john prison now.he copped outstealing n't believe ears",
#  "john prison now.he copped outstealing n't believe ears need",
#  "n't believe ears need need use internet",
#  'need need use internet library card right',
#  'need use internet library card right yes',
#  'library card right yes wait right use computers',
#  'yes wait right use computers ’ fine',
#  'wait right use computers ’ fine would please write name list',
#  '’ fine would please write name list ',
#  'would please write name list  call computer free',
#  ' call computer free log computer',
#  'call computer free log computer use number back library card',
#  'log computer use number back library card thanks ’ sitting',
#  'use number back library card thanks ’ sitting nice tie wearing',
#  'thanks ’ sitting nice tie wearing thank you.but really look right',
#  'nice tie wearing thank you.but really look right certainly.it matches suit perfectly',
#  'thank you.but really look right certainly.it matches suit perfectly go well sweater',
#  'certainly.it matches suit perfectly go well sweater yes.you look smart today',
#  'go well sweater yes.you look smart today thank much',
#  'yes.you look smart today thank much make case',
#  'thank much make case ask ’ think ’ guilty',
#  'make case ask ’ think ’ guilty mean saying',
#  'ask ’ think ’ guilty mean saying mean ’ fault',
#  'mean saying mean ’ fault oh yeah',
#  'mean ’ fault oh yeah yes ’ think pitied rather accused',
#  "oh yeah yes ’ think pitied rather accused happy mother 's day mom",
#  "yes ’ think pitied rather accused happy mother 's day mom thanks beautiful",
#  "happy mother 's day mom thanks beautiful course certainly deserve put us",
#  'thanks beautiful course certainly deserve put us forgot put case deserve flowers',
#  'course certainly deserve put us forgot put case deserve flowers real problem meet people',
#  'forgot put case deserve flowers real problem meet people maybe help',
#  'real problem meet people maybe help never know shake hands tell something',
#  'maybe help never know shake hands tell something come country shake hands',
#  'never know shake hands tell something come country shake hands oh yes men women children shake hands time',
#  'come country shake hands oh yes men women children shake hands time ’ simple men shake hands women children ’',
#  'oh yes men women children shake hands time ’ simple men shake hands women children ’ women shake hands lot children good manners shake hands',
#  '’ simple men shake hands women children ’ women shake hands lot children good manners shake hands well good rule follow men hold hand women children wait see',
#  'women shake hands lot children good manners shake hands well good rule follow men hold hand women children wait see sounds easy enough',
#  'well good rule follow men hold hand women children wait see sounds easy enough sure get hang ’ piece cake ’ nothing worry',
#  'sounds easy enough sure get hang ’ piece cake ’ nothing worry sam sorry birthday yesterday completely forgot',
#  'sure get hang ’ piece cake ’ nothing worry sam sorry birthday yesterday completely forgot worry keep forgetting everyone birthdays well',
#  'sam sorry birthday yesterday completely forgot worry keep forgetting everyone birthdays well margaret really told found forgotten try phone jane must gone',
#  'worry keep forgetting everyone birthdays well margaret really told found forgotten try phone jane must gone yes jane invited dinner new restaurant opened near us',
#  'margaret really told found forgotten try phone jane must gone yes jane invited dinner new restaurant opened near us oh yes know one food',
#  'yes jane invited dinner new restaurant opened near us oh yes know one food food excellent jane ordered birthday cake forgot see one',
#  'oh yes know one food food excellent jane ordered birthday cake forgot see one oh',
#  'food excellent jane ordered birthday cake forgot see one oh yes jane quite upset manager came apologize get free dessert still ...',
#  'oh yes jane quite upset manager came apologize get free dessert still ... would think least could',
#  'yes jane quite upset manager came apologize get free dessert still ... would think least could end nice evening got ipad birthday present wanted',
#  'would think least could end nice evening got ipad birthday present wanted great also thinking getting one think could ask jane quiet word margaret birthday far away',
#  'end nice evening got ipad birthday present wanted great also thinking getting one think could ask jane quiet word margaret birthday far away try knowing margaret see immediately',
#  'great also thinking getting one think could ask jane quiet word margaret birthday far away try knowing margaret see immediately restaurant meeting smiths',
#  'try knowing margaret see immediately restaurant meeting smiths let us go wait',
#  'restaurant meeting smiths let us go wait ',
#  'let us go wait  usually go movies',
#  ' usually go movies usually go free time weekends',
#  'usually go movies usually go free time weekends movie theater always crowded weekends like go movies week',
#  'usually go free time weekends movie theater always crowded weekends like go movies week true sometimes tickets cheaper week well',
#  'movie theater always crowded weekends like go movies week true sometimes tickets cheaper week well telling us lie',
#  'true sometimes tickets cheaper week well telling us lie hanged lying',
#  'telling us lie hanged lying right trouble',
#  'hanged lying right trouble car run petrol',
#  'right trouble car run petrol believe mr fro buy guy think anyway bill gates',
#  'car run petrol believe mr fro buy guy think anyway bill gates lot nerve telling us ads sucked',
#  'believe mr fro buy guy think anyway bill gates lot nerve telling us ads sucked time order balista today want skinny triple latte',
#  'lot nerve telling us ads sucked time order balista today want skinny triple latte start worrying weight',
#  'time order balista today want skinny triple latte start worrying weight feel like drinking whole milk today think fat',
#  'start worrying weight feel like drinking whole milk today think fat jess chill',
#  'feel like drinking whole milk today think fat jess chill come tara let ’ go window buy two tickets movie starting minutes',
#  'jess chill come tara let ’ go window buy two tickets movie starting minutes ’ break line ’ impatient ’ front line soon',
#  'come tara let ’ go window buy two tickets movie starting minutes ’ break line ’ impatient ’ front line soon two tickets please much',
#  '’ break line ’ impatient ’ front line soon two tickets please much oh ari ’ mean pay invited go tonight let ’ go dutch ’ pay way insist',
#  'two tickets please much oh ari ’ mean pay invited go tonight let ’ go dutch ’ pay way insist ’ looking forward film read good review morning ’ newspaper',
#  'oh ari ’ mean pay invited go tonight let ’ go dutch ’ pay way insist ’ looking forward film read good review morning ’ newspaper great see something light funny change ’ tired heavy drama',
#  '’ looking forward film read good review morning ’ newspaper great see something light funny change ’ tired heavy drama seats okay',
#  'great see something light funny change ’ tired heavy drama seats okay ’ fine ’ watch movie without popcorn',
#  'seats okay ’ fine ’ watch movie without popcorn often buy magazines',
#  '’ fine ’ watch movie without popcorn often buy magazines buy computer magazine every month keeps up-to date latest developments',
#  'often buy magazines buy computer magazine every month keeps up-to date latest developments ’ find information internet instead',
#  'buy computer magazine every month keeps up-to date latest developments ’ find information internet instead sometimes takes long find exact information looking besides like read magazine coffee bar sometimes',
#  '’ find information internet instead sometimes takes long find exact information looking besides like read magazine coffee bar sometimes online edition magazine',
#  'sometimes takes long find exact information looking besides like read magazine coffee bar sometimes online edition magazine yes access articles subscription',
#  'online edition magazine yes access articles subscription subscription',
#  'yes access articles subscription subscription yes magazine arrives post beginning month every buy magazines',
#  'subscription yes magazine arrives post beginning month every buy magazines buy look particularly interesting ’ buy regularly',
#  'yes magazine arrives post beginning month every buy magazines buy look particularly interesting ’ buy regularly mumm burgers smell great perfect day barbecue',
#  "buy look particularly interesting ’ buy regularly mumm burgers smell great perfect day barbecue sure glad rain name 's mike gates way",
#  "mumm burgers smell great perfect day barbecue sure glad rain name 's mike gates way oh hi barbara johnson nice meet",
#  "sure glad rain name 's mike gates way oh hi barbara johnson nice meet sorry name",
#  'oh hi barbara johnson nice meet sorry name barbara please call barb',
#  ...]

# %%
trainData = []
testData = []
for i in tqdm(range(len(train_sentence_embeddings))):
    trainData.append((Xtrain2[i],ytrain2[i]))
for i in tqdm(range(len(test_sentence_embeddings))):
    testData.append((Xtest[i],ytest[i]))
# Out:
# 100%|██████████| 5088/5088 [00:00<00:00, 586441.85it/s]
# 100%|██████████| 722/722 [00:00<00:00, 63801.78it/s]

# %%
train_loader = torch.utils.data.DataLoader(dataset=trainData, 
                                           batch_size=32, 
                                           shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=testData, 
                                          batch_size=32, 
                                          shuffle=False)

# %%
para_encoder = SentenceTransformer('sentence-transformers/nli-bert-base', device='cuda')
# Out:
# Downloading:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/375 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
class LSTMClass(nn.Module):
    def __init__(self,para_encoder, hidden_size,num_layers,drop_prob):
        super().__init__()
        self.para_encoder = para_encoder
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size=768,hidden_size=self.hidden_size,num_layers=self.num_layers,batch_first=True,bidirectional=False)
        self.dropout = nn.Dropout(drop_prob)
        self.linear = nn.Linear(hidden_size, 4)
        # self.softmax = nn.Softmax()
        

    def forward(self, x):
      # print("emb",embed_out.shape)
      # print("Senemb",sentence_embed_out.shape)
        para_encoding = self.para_encoder.encode(x, show_progress_bar=False, convert_to_tensor=True) 
        para_encoding = para_encoding.unsqueeze(1)
        hnot = torch.zeros(self.num_layers,x.size(0),self.hidden_size).to(device)
        cnot = torch.zeros(self.num_layers,x.size(0),self.hidden_size).to(device)
        out,_ = self.lstm(x,(hnot,cnot))
        out = out[:,-1,:]
        # print("lstm",out.shape)
        # out = self.dropout(out)
        out = self.linear(out)
        # print("lin",out.shape)
        # out = self.softmax(out)
        return out

# %%
lstm = LSTMClass(para_encoder,128,2,0.2).to(device)
criterion = nn.CrossEntropyLoss()
# criterion = nn.L1Loss()
optimizer = optim.Adam(lstm.parameters(), lr=0.0001)

# %%
numEpochs = 20
for epoch in range(numEpochs):  # loop over the dataset multiple times

    running_loss = 0.0
    print("epoch:", epoch)
    for i, data in tqdm(enumerate(train_loader)):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        print(inputs)
        inputs = inputs.to(device)
        labels = labels.to(device)

        inputs = torch.unsqueeze(inputs, 1)
#         print(inputs.shape, labels.shape)
        # print("l",labels.shape)
        # print(labels)
#         inputs = torch.squeeze(inputs,0)
        # print(inputs.shape)
        # print(inputs)
        
        outputs = lstm(inputs)
        
          
        # outputs = torch.squeeze(outputs)
        # outputs = outputs.reshape((-1, 1))
        # print(outputs.shape)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    
#         if (i+1) % 10 == 0:
#         print(f'Epoch {epoch + 1} / {numEpochs}, Step {i+1} / {totalSteps}, Loss: {loss.item():.4f}')
            # print(outputs)

print('Finished Training')
# Out:
# 0it [00:00, ?it/s]
# epoch: 0
# ('say jim going beers dinner know tempting really good fitness mean help us relax', 'know tempting really good fitness mean help us relax really think make us fat act silly remember last time', 'mean help us relax really think make us fat act silly remember last time guess right.but shall feel like sitting home', 'really think make us fat act silly remember last time guess right.but shall feel like sitting home suggest walk gym play singsong meet friends', 'guess right.but shall feel like sitting home suggest walk gym play singsong meet friends good idea hear mary sally often go play pingpong.perhaps make foursome', 'suggest walk gym play singsong meet friends good idea hear mary sally often go play pingpong.perhaps make foursome sounds great willing could ask go dancing us.that excellent exercise fun', 'good idea hear mary sally often go play pingpong.perhaps make foursome sounds great willing could ask go dancing us.that excellent exercise fun good.let go', 'sounds great willing could ask go dancing us.that excellent exercise fun good.let go right', 'good.let go right push-ups', 'right push-ups course piece cake believe 30 push-ups minute', 'push-ups course piece cake believe 30 push-ups minute really think impossible', 'course piece cake believe 30 push-ups minute really think impossible mean 30 push-ups', 'really think impossible mean 30 push-ups yeah', 'mean 30 push-ups yeah easy exercise everyday make', 'yeah easy exercise everyday make study radio', 'easy exercise everyday make study radio listen background music', 'study radio listen background music difference', 'listen background music difference radio many comerials', 'difference radio many comerials true buy record player', 'radio many comerials true buy record player right', 'true buy record player right right soon terrified watched fall wire', 'right right soon terrified watched fall wire worry.he acrobat 。', 'right soon terrified watched fall wire worry.he acrobat 。 see', 'worry.he acrobat 。 see hey john nice skates new', 'see hey john nice skates new yeah got started playing ice hockey community league finally got new skates', 'hey john nice skates new yeah got started playing ice hockey community league finally got new skates position play', 'yeah got started playing ice hockey community league finally got new skates position play ’ defender ’ lot fun ’ able skate fast defense', 'position play ’ defender ’ lot fun ’ able skate fast defense yeah ’ pretty big guy play goalie', '’ defender ’ lot fun ’ able skate fast defense yeah ’ pretty big guy play goalie oh yeah team', 'yeah ’ pretty big guy play goalie oh yeah team rockets', 'oh yeah team rockets really think play guys next week well go practice see later', 'rockets really think play guys next week well go practice see later right see later')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-258-e55aff5be060> in <module>
#       8         inputs, labels = data
#       9         print(inputs)
# ---> 10         inputs = inputs.to(device)
#      11         labels = labels.to(device)
#      12
#
# AttributeError: 'tuple' object has no attribute 'to'

# %%
with torch.no_grad():
    nCorrect = 0
    nSamples = 0
    nClassCorrect = [0 for i in range(4)]
    nClassTotal = [0 for i in range(4)]
    
        
    for i,data in tqdm(enumerate(test_loader)):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs = inputs.to(device)
        inputs = torch.unsqueeze(inputs, 1)
        # print("l",labels.shape)
        # print(labels)
        labels = labels.to(device)
        # print("l",labels.shape)
        # print(labels)
#         inputs = torch.squeeze(inputs, 0)
        outputs = lstm(inputs)

        # outputs = outputs.reshape((-1, 1))
        # print(outputs.shape)
        _, predictions = torch.max(outputs,1)
#         print(predictions)
#         print("l",labels)
        nSamples += labels.shape[0]
        # nCorrect += (predictions == labels).sum().item()
        for i in range(len(predictions)):
            if predictions[i] == labels[i]:
                nCorrect += 1

    
    acc = 100.0 * nCorrect / nSamples
    print(f'Accuracy on test: {acc:.2f}%')
# Out:
# 23it [00:00, 681.00it/s]
# Accuracy on test: 50.83%
